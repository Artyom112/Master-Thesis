# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

n_steps = 50
forecast = 10

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

#LOAD DATA
data_west = pd.read_csv('denoised_data_1016_west.csv')
data_west_o = np.array(data_west.FLOW)
# #EXRTEND DATA
array_to_concatinate = data_west_o[288:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

# #SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)
flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
print(flow_reshaped.shape)

# #TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train= flow_reshaped[:test, :n_steps] #first 50, last 10
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

# # NEW MODEL TO FIT HYPERPARAMETERS
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True), 
    keras.layers.TimeDistributed(keras.layers.Dense(forecast))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer="adam",  metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("rnn_1016_west.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])


#50 minutes forecast
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time")
    plt.ylabel('Volume')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (10545, 60, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7381 samples, validate on 2109 samples
# Epoch 1/700
# 7381/7381 [==============================] - 4s 593us/sample - loss: 0.0213 - last_time_step_mse: 0.0213 - val_loss: 0.0080 - val_last_time_step_mse: 0.0075
# Epoch 2/700
# 7381/7381 [==============================] - 3s 467us/sample - loss: 0.0075 - last_time_step_mse: 0.0071 - val_loss: 0.0071 - val_last_time_step_mse: 0.0070
# Epoch 3/700
# 7381/7381 [==============================] - 4s 519us/sample - loss: 0.0070 - last_time_step_mse: 0.0069 - val_loss: 0.0069 - val_last_time_step_mse: 0.0069
# Epoch 4/700
# 7381/7381 [==============================] - 4s 527us/sample - loss: 0.0069 - last_time_step_mse: 0.0068 - val_loss: 0.0068 - val_last_time_step_mse: 0.0068
# Epoch 5/700
# 7381/7381 [==============================] - 4s 537us/sample - loss: 0.0068 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 6/700
# 7381/7381 [==============================] - 4s 532us/sample - loss: 0.0067 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 7/700
# 7381/7381 [==============================] - 4s 553us/sample - loss: 0.0067 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 8/700
# 7381/7381 [==============================] - 4s 523us/sample - loss: 0.0067 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 9/700
# 7381/7381 [==============================] - 4s 527us/sample - loss: 0.0067 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 10/700
# 7381/7381 [==============================] - 4s 528us/sample - loss: 0.0067 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 11/700
# 7381/7381 [==============================] - 4s 537us/sample - loss: 0.0067 - last_time_step_mse: 0.0067 - val_loss: 0.0067 - val_last_time_step_mse: 0.0068
# Epoch 12/700
# 7381/7381 [==============================] - 4s 509us/sample - loss: 0.0067 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 13/700
# 7381/7381 [==============================] - 4s 525us/sample - loss: 0.0067 - last_time_step_mse: 0.0066 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 14/700
# 7381/7381 [==============================] - 4s 498us/sample - loss: 0.0067 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 15/700
# 7381/7381 [==============================] - 4s 535us/sample - loss: 0.0067 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 16/700
# 7381/7381 [==============================] - 4s 534us/sample - loss: 0.0067 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 17/700
# 7381/7381 [==============================] - 4s 506us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 18/700
# 7381/7381 [==============================] - 4s 521us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 19/700
# 7381/7381 [==============================] - 4s 536us/sample - loss: 0.0067 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 20/700
# 7381/7381 [==============================] - 4s 551us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 21/700
# 7381/7381 [==============================] - 4s 558us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 22/700
# 7381/7381 [==============================] - 4s 541us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 23/700
# 7381/7381 [==============================] - 4s 550us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 24/700
# 7381/7381 [==============================] - 4s 552us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 25/700
# 7381/7381 [==============================] - 4s 553us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 26/700
# 7381/7381 [==============================] - 4s 532us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0067 - val_last_time_step_mse: 0.0066
# Epoch 27/700
# 7381/7381 [==============================] - 4s 526us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0067 - val_last_time_step_mse: 0.0067
# Epoch 28/700
# 7381/7381 [==============================] - 4s 539us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0067 - val_last_time_step_mse: 0.0066
# Epoch 29/700
# 7381/7381 [==============================] - 4s 529us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 30/700
# 7381/7381 [==============================] - 4s 524us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 31/700
# 7381/7381 [==============================] - 4s 518us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 32/700
# 7381/7381 [==============================] - 4s 513us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 33/700
# 7381/7381 [==============================] - 4s 502us/sample - loss: 0.0066 - last_time_step_mse: 0.0066 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 34/700
# 7381/7381 [==============================] - 4s 502us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 35/700
# 7381/7381 [==============================] - 4s 520us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 36/700
# 7381/7381 [==============================] - 4s 522us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 37/700
# 7381/7381 [==============================] - 4s 531us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0065
# Epoch 38/700
# 7381/7381 [==============================] - 4s 545us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0065
# Epoch 39/700
# 7381/7381 [==============================] - 4s 552us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0065
# Epoch 40/700
# 7381/7381 [==============================] - 4s 521us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 41/700
# 7381/7381 [==============================] - 4s 505us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0066 - val_last_time_step_mse: 0.0065
# Epoch 42/700
# 7381/7381 [==============================] - 4s 513us/sample - loss: 0.0066 - last_time_step_mse: 0.0065 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 43/700
# 7381/7381 [==============================] - 4s 516us/sample - loss: 0.0066 - last_time_step_mse: 0.0064 - val_loss: 0.0066 - val_last_time_step_mse: 0.0065
# Epoch 44/700
# 7381/7381 [==============================] - 4s 520us/sample - loss: 0.0066 - last_time_step_mse: 0.0064 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 45/700
# 7381/7381 [==============================] - 4s 527us/sample - loss: 0.0066 - last_time_step_mse: 0.0064 - val_loss: 0.0066 - val_last_time_step_mse: 0.0065
# Epoch 46/700
# 7381/7381 [==============================] - 4s 502us/sample - loss: 0.0066 - last_time_step_mse: 0.0064 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 47/700
# 7381/7381 [==============================] - 4s 539us/sample - loss: 0.0065 - last_time_step_mse: 0.0064 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 48/700
# 7381/7381 [==============================] - 4s 526us/sample - loss: 0.0065 - last_time_step_mse: 0.0064 - val_loss: 0.0065 - val_last_time_step_mse: 0.0064
# Epoch 49/700
# 7381/7381 [==============================] - 4s 522us/sample - loss: 0.0065 - last_time_step_mse: 0.0064 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 50/700
# 7381/7381 [==============================] - 4s 522us/sample - loss: 0.0065 - last_time_step_mse: 0.0064 - val_loss: 0.0066 - val_last_time_step_mse: 0.0066
# Epoch 51/700
# 7381/7381 [==============================] - 4s 515us/sample - loss: 0.0065 - last_time_step_mse: 0.0063 - val_loss: 0.0065 - val_last_time_step_mse: 0.0064
# Epoch 52/700
# 7381/7381 [==============================] - 4s 505us/sample - loss: 0.0065 - last_time_step_mse: 0.0063 - val_loss: 0.0065 - val_last_time_step_mse: 0.0064
# Epoch 53/700
# 7381/7381 [==============================] - 4s 489us/sample - loss: 0.0065 - last_time_step_mse: 0.0063 - val_loss: 0.0065 - val_last_time_step_mse: 0.0064
# Epoch 54/700
# 7381/7381 [==============================] - 4s 524us/sample - loss: 0.0065 - last_time_step_mse: 0.0063 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 55/700
# 7381/7381 [==============================] - 3s 442us/sample - loss: 0.0065 - last_time_step_mse: 0.0063 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 56/700
# 7381/7381 [==============================] - 3s 467us/sample - loss: 0.0065 - last_time_step_mse: 0.0063 - val_loss: 0.0065 - val_last_time_step_mse: 0.0064
# Epoch 57/700
# 7381/7381 [==============================] - 4s 523us/sample - loss: 0.0064 - last_time_step_mse: 0.0063 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 58/700
# 7381/7381 [==============================] - 4s 524us/sample - loss: 0.0064 - last_time_step_mse: 0.0063 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 59/700
# 7381/7381 [==============================] - 3s 455us/sample - loss: 0.0064 - last_time_step_mse: 0.0063 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 60/700
# 7381/7381 [==============================] - 4s 493us/sample - loss: 0.0064 - last_time_step_mse: 0.0063 - val_loss: 0.0064 - val_last_time_step_mse: 0.0063
# Epoch 61/700
# 7381/7381 [==============================] - 3s 467us/sample - loss: 0.0064 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 62/700
# 7381/7381 [==============================] - 3s 441us/sample - loss: 0.0064 - last_time_step_mse: 0.0062 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 63/700
# 7381/7381 [==============================] - 4s 500us/sample - loss: 0.0064 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 64/700
# 7381/7381 [==============================] - 4s 512us/sample - loss: 0.0064 - last_time_step_mse: 0.0062 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 65/700
# 7381/7381 [==============================] - 4s 505us/sample - loss: 0.0064 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 66/700
# 7381/7381 [==============================] - 4s 494us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0064 - val_last_time_step_mse: 0.0065
# Epoch 67/700
# 7381/7381 [==============================] - 3s 461us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 68/700
# 7381/7381 [==============================] - 4s 481us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 69/700
# 7381/7381 [==============================] - 4s 480us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 70/700
# 7381/7381 [==============================] - 4s 483us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 71/700
# 7381/7381 [==============================] - 3s 453us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 72/700
# 7381/7381 [==============================] - 3s 442us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 73/700
# 7381/7381 [==============================] - 3s 444us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 74/700
# 7381/7381 [==============================] - 4s 483us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0064 - val_last_time_step_mse: 0.0064
# Epoch 75/700
# 7381/7381 [==============================] - 4s 507us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 76/700
# 7381/7381 [==============================] - 3s 450us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 77/700
# 7381/7381 [==============================] - 4s 510us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 78/700
# 7381/7381 [==============================] - 4s 503us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 79/700
# 7381/7381 [==============================] - 4s 511us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 80/700
# 7381/7381 [==============================] - 4s 510us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 81/700
# 7381/7381 [==============================] - 4s 515us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 82/700
# 7381/7381 [==============================] - 4s 479us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0064
# Epoch 83/700
# 7381/7381 [==============================] - 4s 510us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 84/700
# 7381/7381 [==============================] - 4s 495us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 85/700
# 7381/7381 [==============================] - 4s 477us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 86/700
# 7381/7381 [==============================] - 3s 436us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 87/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 88/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 89/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 90/700
# 7381/7381 [==============================] - 3s 444us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 91/700
# 7381/7381 [==============================] - 3s 459us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 92/700
# 7381/7381 [==============================] - 4s 501us/sample - loss: 0.0063 - last_time_step_mse: 0.0062 - val_loss: 0.0063 - val_last_time_step_mse: 0.0061
# Epoch 93/700
# 7381/7381 [==============================] - 4s 505us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 94/700
# 7381/7381 [==============================] - 4s 516us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 95/700
# 7381/7381 [==============================] - 4s 513us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 96/700
# 7381/7381 [==============================] - 4s 509us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 97/700
# 7381/7381 [==============================] - 4s 479us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0062
# Epoch 98/700
# 7381/7381 [==============================] - 4s 505us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 99/700
# 7381/7381 [==============================] - 4s 512us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 100/700
# 7381/7381 [==============================] - 4s 516us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 101/700
# 7381/7381 [==============================] - 4s 511us/sample - loss: 0.0063 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 102/700
# 7381/7381 [==============================] - 4s 514us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 103/700
# 7381/7381 [==============================] - 4s 508us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 104/700
# 7381/7381 [==============================] - 4s 514us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 105/700
# 7381/7381 [==============================] - 4s 517us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 106/700
# 7381/7381 [==============================] - 4s 527us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 107/700
# 7381/7381 [==============================] - 4s 511us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 108/700
# 7381/7381 [==============================] - 4s 505us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0063 - val_last_time_step_mse: 0.0063
# Epoch 109/700
# 7381/7381 [==============================] - 4s 513us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 110/700
# 7381/7381 [==============================] - 4s 506us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 111/700
# 7381/7381 [==============================] - 4s 511us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 112/700
# 7381/7381 [==============================] - 4s 504us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0064
# Epoch 113/700
# 7381/7381 [==============================] - 4s 519us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 114/700
# 7381/7381 [==============================] - 4s 513us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 115/700
# 7381/7381 [==============================] - 4s 520us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 116/700
# 7381/7381 [==============================] - 4s 487us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 117/700
# 7381/7381 [==============================] - 4s 520us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 118/700
# 7381/7381 [==============================] - 4s 490us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 119/700
# 7381/7381 [==============================] - 4s 517us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0060
# Epoch 120/700
# 7381/7381 [==============================] - 4s 524us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0063
# Epoch 121/700
# 7381/7381 [==============================] - 4s 525us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 122/700
# 7381/7381 [==============================] - 4s 518us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 123/700
# 7381/7381 [==============================] - 4s 535us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 124/700
# 7381/7381 [==============================] - 4s 544us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 125/700
# 7381/7381 [==============================] - 4s 523us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0060
# Epoch 126/700
# 7381/7381 [==============================] - 4s 519us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 127/700
# 7381/7381 [==============================] - 4s 524us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 128/700
# 7381/7381 [==============================] - 4s 511us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 129/700
# 7381/7381 [==============================] - 4s 512us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0060
# Epoch 130/700
# 7381/7381 [==============================] - 4s 519us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0060
# Epoch 131/700
# 7381/7381 [==============================] - 4s 506us/sample - loss: 0.0061 - last_time_step_mse: 0.0060 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 132/700
# 7381/7381 [==============================] - 4s 519us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 133/700
# 7381/7381 [==============================] - 4s 518us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 134/700
# 7381/7381 [==============================] - 4s 510us/sample - loss: 0.0061 - last_time_step_mse: 0.0060 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 135/700
# 7381/7381 [==============================] - 4s 478us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0063 - val_last_time_step_mse: 0.0064
# Epoch 136/700
# 7381/7381 [==============================] - 4s 501us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0063
# Epoch 137/700
# 7381/7381 [==============================] - 3s 467us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 138/700
# 7381/7381 [==============================] - 4s 494us/sample - loss: 0.0061 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# Epoch 139/700
# 7381/7381 [==============================] - 3s 467us/sample - loss: 0.0061 - last_time_step_mse: 0.0060 - val_loss: 0.0062 - val_last_time_step_mse: 0.0062
# Epoch 140/700
# 7381/7381 [==============================] - 3s 462us/sample - loss: 0.0061 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0061
# (10, 1)
# (10, 1)
# (10,)
