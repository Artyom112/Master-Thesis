# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

n_steps = 50
forecast = 10

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

#LOAD DATA
data_west = pd.read_csv('denoised_data_1015_west.csv')
data_west_o = np.array(data_west.FLOW)
# #EXRTEND DATA
array_to_concatinate = data_west_o[288:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

# #SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)
flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
print(flow_reshaped.shape)

# #TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train= flow_reshaped[:test, :n_steps] #first 50, last 10
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

# # NEW MODEL TO FIT HYPERPARAMETERS
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True), 
    keras.layers.TimeDistributed(keras.layers.Dense(forecast))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer="adam",  metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("rnn_1014_norht.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])


#50 minutes forecast
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time")
    plt.ylabel('Volume')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (10545, 60, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7381 samples, validate on 2109 samples
# Epoch 1/700
# 7381/7381 [==============================] - 4s 567us/sample - loss: 0.0169 - last_time_step_mse: 0.0147 - val_loss: 0.0047 - val_last_time_step_mse: 0.0033
# Epoch 2/700
# 7381/7381 [==============================] - 4s 482us/sample - loss: 0.0041 - last_time_step_mse: 0.0032 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 3/700
# 7381/7381 [==============================] - 4s 481us/sample - loss: 0.0035 - last_time_step_mse: 0.0031 - val_loss: 0.0035 - val_last_time_step_mse: 0.0030
# Epoch 4/700
# 7381/7381 [==============================] - 4s 483us/sample - loss: 0.0033 - last_time_step_mse: 0.0031 - val_loss: 0.0033 - val_last_time_step_mse: 0.0030
# Epoch 5/700
# 7381/7381 [==============================] - 4s 481us/sample - loss: 0.0032 - last_time_step_mse: 0.0030 - val_loss: 0.0032 - val_last_time_step_mse: 0.0030
# Epoch 6/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0032 - last_time_step_mse: 0.0030 - val_loss: 0.0031 - val_last_time_step_mse: 0.0029
# Epoch 7/700
# 7381/7381 [==============================] - 4s 496us/sample - loss: 0.0031 - last_time_step_mse: 0.0029 - val_loss: 0.0031 - val_last_time_step_mse: 0.0028
# Epoch 8/700
# 7381/7381 [==============================] - 4s 494us/sample - loss: 0.0031 - last_time_step_mse: 0.0029 - val_loss: 0.0031 - val_last_time_step_mse: 0.0028
# Epoch 9/700
# 7381/7381 [==============================] - 4s 493us/sample - loss: 0.0031 - last_time_step_mse: 0.0029 - val_loss: 0.0031 - val_last_time_step_mse: 0.0029
# Epoch 10/700
# 7381/7381 [==============================] - 4s 490us/sample - loss: 0.0030 - last_time_step_mse: 0.0028 - val_loss: 0.0031 - val_last_time_step_mse: 0.0028
# Epoch 11/700
# 7381/7381 [==============================] - 4s 489us/sample - loss: 0.0030 - last_time_step_mse: 0.0028 - val_loss: 0.0030 - val_last_time_step_mse: 0.0028
# Epoch 12/700
# 7381/7381 [==============================] - 4s 490us/sample - loss: 0.0030 - last_time_step_mse: 0.0028 - val_loss: 0.0030 - val_last_time_step_mse: 0.0027
# Epoch 13/700
# 7381/7381 [==============================] - 4s 493us/sample - loss: 0.0030 - last_time_step_mse: 0.0028 - val_loss: 0.0030 - val_last_time_step_mse: 0.0027
# Epoch 14/700
# 7381/7381 [==============================] - 4s 497us/sample - loss: 0.0029 - last_time_step_mse: 0.0028 - val_loss: 0.0029 - val_last_time_step_mse: 0.0027
# Epoch 15/700
# 7381/7381 [==============================] - 4s 495us/sample - loss: 0.0029 - last_time_step_mse: 0.0028 - val_loss: 0.0029 - val_last_time_step_mse: 0.0028
# Epoch 16/700
# 7381/7381 [==============================] - 4s 476us/sample - loss: 0.0029 - last_time_step_mse: 0.0028 - val_loss: 0.0029 - val_last_time_step_mse: 0.0028
# Epoch 17/700
# 7381/7381 [==============================] - 4s 480us/sample - loss: 0.0029 - last_time_step_mse: 0.0028 - val_loss: 0.0029 - val_last_time_step_mse: 0.0027
# Epoch 18/700
# 7381/7381 [==============================] - 4s 483us/sample - loss: 0.0029 - last_time_step_mse: 0.0027 - val_loss: 0.0029 - val_last_time_step_mse: 0.0027
# Epoch 19/700
# 7381/7381 [==============================] - 4s 485us/sample - loss: 0.0028 - last_time_step_mse: 0.0027 - val_loss: 0.0028 - val_last_time_step_mse: 0.0026
# Epoch 20/700
# 7381/7381 [==============================] - 4s 482us/sample - loss: 0.0028 - last_time_step_mse: 0.0026 - val_loss: 0.0028 - val_last_time_step_mse: 0.0026
# Epoch 21/700
# 7381/7381 [==============================] - 4s 478us/sample - loss: 0.0027 - last_time_step_mse: 0.0026 - val_loss: 0.0027 - val_last_time_step_mse: 0.0025
# Epoch 22/700
# 7381/7381 [==============================] - 4s 480us/sample - loss: 0.0027 - last_time_step_mse: 0.0025 - val_loss: 0.0027 - val_last_time_step_mse: 0.0024
# Epoch 23/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0026 - last_time_step_mse: 0.0025 - val_loss: 0.0026 - val_last_time_step_mse: 0.0024
# Epoch 24/700
# 7381/7381 [==============================] - 4s 483us/sample - loss: 0.0026 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0023
# Epoch 25/700
# 7381/7381 [==============================] - 4s 489us/sample - loss: 0.0026 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0024
# Epoch 26/700
# 7381/7381 [==============================] - 4s 482us/sample - loss: 0.0026 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0023
# Epoch 27/700
# 7381/7381 [==============================] - 4s 487us/sample - loss: 0.0026 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0023
# Epoch 28/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0025 - last_time_step_mse: 0.0024 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 29/700
# 7381/7381 [==============================] - 4s 481us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 30/700
# 7381/7381 [==============================] - 4s 481us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 31/700
# 7381/7381 [==============================] - 4s 485us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0026 - val_last_time_step_mse: 0.0023
# Epoch 32/700
# 7381/7381 [==============================] - 4s 485us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0026 - val_last_time_step_mse: 0.0023
# Epoch 33/700
# 7381/7381 [==============================] - 4s 485us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 34/700
# 7381/7381 [==============================] - 4s 482us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 35/700
# 7381/7381 [==============================] - 4s 486us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 36/700
# 7381/7381 [==============================] - 4s 488us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 37/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 38/700
# 7381/7381 [==============================] - 4s 487us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 39/700
# 7381/7381 [==============================] - 4s 482us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 40/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 41/700
# 7381/7381 [==============================] - 4s 483us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 42/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 43/700
# 7381/7381 [==============================] - 4s 486us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 44/700
# 7381/7381 [==============================] - 4s 481us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 45/700
# 7381/7381 [==============================] - 4s 488us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 46/700
# 7381/7381 [==============================] - 4s 489us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0025 - val_last_time_step_mse: 0.0021
# Epoch 47/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 48/700
# 7381/7381 [==============================] - 4s 484us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 49/700
# 7381/7381 [==============================] - 4s 491us/sample - loss: 0.0024 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 50/700
# 7381/7381 [==============================] - 4s 487us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.