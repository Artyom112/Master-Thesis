# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1016_east.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o[288:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)

flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
print(flow_reshaped.shape)
# #TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_train.shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]
print(y_train.shape)

#DEFINE AND COMPILE MODEL
model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(forecast))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("lstm_1016_east_nomet.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MINS PREDICTION
# model = keras.models.load_model("lstm_1016_east_nomet.h5")

flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time")
    plt.ylabel('Volume')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (10545, 60, 1)
# (7381, 50, 1)
# (7381, 50, 10)
# Train on 7381 samples, validate on 2109 samples
# Epoch 1/700
# 7381/7381 [==============================] - 28s 4ms/sample - loss: 0.0142 - last_time_step_mse: 0.0120 - val_loss: 0.0086 - val_last_time_step_mse: 0.0073
# Epoch 2/700
# 7381/7381 [==============================] - 26s 4ms/sample - loss: 0.0077 - last_time_step_mse: 0.0066 - val_loss: 0.0071 - val_last_time_step_mse: 0.0064
# Epoch 3/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0067 - last_time_step_mse: 0.0061 - val_loss: 0.0066 - val_last_time_step_mse: 0.0061
# Epoch 4/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0063 - last_time_step_mse: 0.0059 - val_loss: 0.0062 - val_last_time_step_mse: 0.0058
# Epoch 5/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0061 - last_time_step_mse: 0.0058 - val_loss: 0.0060 - val_last_time_step_mse: 0.0055
# Epoch 6/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0058 - last_time_step_mse: 0.0055 - val_loss: 0.0057 - val_last_time_step_mse: 0.0051
# Epoch 7/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0055 - last_time_step_mse: 0.0051 - val_loss: 0.0054 - val_last_time_step_mse: 0.0047
# Epoch 8/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0053 - last_time_step_mse: 0.0049 - val_loss: 0.0053 - val_last_time_step_mse: 0.0045
# Epoch 9/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0052 - val_last_time_step_mse: 0.0045
# Epoch 10/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0051 - last_time_step_mse: 0.0047 - val_loss: 0.0050 - val_last_time_step_mse: 0.0042
# Epoch 11/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0050 - last_time_step_mse: 0.0046 - val_loss: 0.0050 - val_last_time_step_mse: 0.0041
# Epoch 12/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0050 - val_last_time_step_mse: 0.0042
# Epoch 13/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0049 - val_last_time_step_mse: 0.0041
# Epoch 14/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0039
# Epoch 15/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0047 - val_last_time_step_mse: 0.0039
# Epoch 16/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0047 - last_time_step_mse: 0.0042 - val_loss: 0.0047 - val_last_time_step_mse: 0.0039
# Epoch 17/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0047 - last_time_step_mse: 0.0042 - val_loss: 0.0047 - val_last_time_step_mse: 0.0038
# Epoch 18/700
# 7381/7381 [==============================] - 26s 4ms/sample - loss: 0.0046 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0038
# Epoch 19/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0046 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0038
# Epoch 20/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0046 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0038
# Epoch 21/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0037
# Epoch 22/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0045 - last_time_step_mse: 0.0040 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 23/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0045 - last_time_step_mse: 0.0040 - val_loss: 0.0046 - val_last_time_step_mse: 0.0038
# Epoch 24/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0045 - last_time_step_mse: 0.0040 - val_loss: 0.0045 - val_last_time_step_mse: 0.0036
# Epoch 25/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0045 - last_time_step_mse: 0.0040 - val_loss: 0.0045 - val_last_time_step_mse: 0.0036
# Epoch 26/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0045 - val_last_time_step_mse: 0.0037
# Epoch 27/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0044 - last_time_step_mse: 0.0039 - val_loss: 0.0045 - val_last_time_step_mse: 0.0037
# Epoch 28/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0044 - last_time_step_mse: 0.0039 - val_loss: 0.0044 - val_last_time_step_mse: 0.0036
# Epoch 29/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0044 - last_time_step_mse: 0.0039 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 30/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0044 - last_time_step_mse: 0.0039 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 31/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0044 - last_time_step_mse: 0.0038 - val_loss: 0.0044 - val_last_time_step_mse: 0.0035
# Epoch 32/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0044 - val_last_time_step_mse: 0.0035
# Epoch 33/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0043 - val_last_time_step_mse: 0.0035
# Epoch 34/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0044 - val_last_time_step_mse: 0.0036
# Epoch 35/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0044 - val_last_time_step_mse: 0.0035
# Epoch 36/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0043 - val_last_time_step_mse: 0.0035
# Epoch 37/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0037 - val_loss: 0.0042 - val_last_time_step_mse: 0.0034
# Epoch 38/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0043 - val_last_time_step_mse: 0.0035
# Epoch 39/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0042 - last_time_step_mse: 0.0037 - val_loss: 0.0043 - val_last_time_step_mse: 0.0036
# Epoch 40/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0042 - last_time_step_mse: 0.0037 - val_loss: 0.0042 - val_last_time_step_mse: 0.0034
# Epoch 41/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0042 - last_time_step_mse: 0.0037 - val_loss: 0.0042 - val_last_time_step_mse: 0.0034
# Epoch 42/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0042 - last_time_step_mse: 0.0036 - val_loss: 0.0042 - val_last_time_step_mse: 0.0034
# Epoch 43/700
# 7381/7381 [==============================] - 26s 4ms/sample - loss: 0.0042 - last_time_step_mse: 0.0036 - val_loss: 0.0042 - val_last_time_step_mse: 0.0034
# Epoch 44/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0042 - last_time_step_mse: 0.0036 - val_loss: 0.0041 - val_last_time_step_mse: 0.0033
# Epoch 45/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0041 - last_time_step_mse: 0.0036 - val_loss: 0.0043 - val_last_time_step_mse: 0.0034
# Epoch 46/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0041 - last_time_step_mse: 0.0036 - val_loss: 0.0041 - val_last_time_step_mse: 0.0033
# Epoch 47/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0041 - last_time_step_mse: 0.0036 - val_loss: 0.0041 - val_last_time_step_mse: 0.0033
# Epoch 48/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0041 - last_time_step_mse: 0.0035 - val_loss: 0.0041 - val_last_time_step_mse: 0.0033
# Epoch 49/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0041 - last_time_step_mse: 0.0035 - val_loss: 0.0041 - val_last_time_step_mse: 0.0033
# Epoch 50/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0040 - last_time_step_mse: 0.0035 - val_loss: 0.0040 - val_last_time_step_mse: 0.0032
# Epoch 51/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0040 - last_time_step_mse: 0.0034 - val_loss: 0.0041 - val_last_time_step_mse: 0.0032
# Epoch 52/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0040 - last_time_step_mse: 0.0034 - val_loss: 0.0041 - val_last_time_step_mse: 0.0032
# Epoch 53/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0040 - last_time_step_mse: 0.0034 - val_loss: 0.0040 - val_last_time_step_mse: 0.0032
# Epoch 54/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0040 - last_time_step_mse: 0.0033 - val_loss: 0.0040 - val_last_time_step_mse: 0.0032
# Epoch 55/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0040 - val_last_time_step_mse: 0.0032
# Epoch 56/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0040 - val_last_time_step_mse: 0.0032
# Epoch 57/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 58/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0032 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 59/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0032 - val_loss: 0.0039 - val_last_time_step_mse: 0.0030
# Epoch 60/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0032 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 61/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 62/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0039 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 63/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 64/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 65/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 66/700
# 7381/7381 [==============================] - 26s 4ms/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 67/700
# 7381/7381 [==============================] - 26s 4ms/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 68/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 69/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 70/700
# 7381/7381 [==============================] - 26s 3ms/sample - loss: 0.0038 - last_time_step_mse: 0.0030 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 71/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 72/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 73/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 74/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 75/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0038 - val_last_time_step_mse: 0.0029
# Epoch 76/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0028
# Epoch 77/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0028
# Epoch 78/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0029 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 79/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 80/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 81/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 82/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 83/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0029 - val_loss: 0.0037 - val_last_time_step_mse: 0.0028
# Epoch 84/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0037 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 85/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0037 - val_last_time_step_mse: 0.0028
# Epoch 86/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 87/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 88/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 89/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 90/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 91/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 92/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 93/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 94/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 95/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 96/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 97/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 98/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0035 - val_last_time_step_mse: 0.0027
# Epoch 99/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 100/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 101/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 102/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0036 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 103/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0035 - last_time_step_mse: 0.0028 - val_loss: 0.0035 - val_last_time_step_mse: 0.0027
# Epoch 104/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0035 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 105/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0035 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 106/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0035 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 107/700
# 7381/7381 [==============================] - 24s 3ms/sample - loss: 0.0035 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# Epoch 108/700
# 7381/7381 [==============================] - 25s 3ms/sample - loss: 0.0035 - last_time_step_mse: 0.0028 - val_loss: 0.0036 - val_last_time_step_mse: 0.0027
# (10, 1)
# (10, 1)
# (10,)
