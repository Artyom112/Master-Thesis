# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1015_south.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o[175:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)

flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
#TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_test.shape)
print(X_test[-1:].shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

#MODEL
def last_time_step_mse(Y_true, Y_pred):
     return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=1000,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("vawenet_1014_south.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MIN FORECAST
#50 MIN FORECAST
#flow
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time (in 5 minutes intervals)")
    plt.ylabel('Volume (veh/h)')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (1020, 50, 1)
# (1, 50, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7138 samples, validate on 2040 samples
# Epoch 1/1000
# 7138/7138 [==============================] - 5s 742us/sample - loss: 0.0335 - last_time_step_mse: 0.0281 - val_loss: 0.0070 - val_last_time_step_mse: 0.0067
# Epoch 2/1000
# 7138/7138 [==============================] - 4s 630us/sample - loss: 0.0068 - last_time_step_mse: 0.0065 - val_loss: 0.0068 - val_last_time_step_mse: 0.0068
# Epoch 3/1000
# 7138/7138 [==============================] - 5s 642us/sample - loss: 0.0066 - last_time_step_mse: 0.0064 - val_loss: 0.0070 - val_last_time_step_mse: 0.0072
# Epoch 4/1000
# 7138/7138 [==============================] - 5s 634us/sample - loss: 0.0064 - last_time_step_mse: 0.0062 - val_loss: 0.0062 - val_last_time_step_mse: 0.0060
# Epoch 5/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0062 - last_time_step_mse: 0.0060 - val_loss: 0.0061 - val_last_time_step_mse: 0.0060
# Epoch 6/1000
# 7138/7138 [==============================] - 4s 627us/sample - loss: 0.0061 - last_time_step_mse: 0.0059 - val_loss: 0.0065 - val_last_time_step_mse: 0.0065
# Epoch 7/1000
# 7138/7138 [==============================] - 5s 640us/sample - loss: 0.0060 - last_time_step_mse: 0.0058 - val_loss: 0.0063 - val_last_time_step_mse: 0.0061
# Epoch 8/1000
# 7138/7138 [==============================] - 5s 654us/sample - loss: 0.0060 - last_time_step_mse: 0.0057 - val_loss: 0.0066 - val_last_time_step_mse: 0.0067
# Epoch 9/1000
# 7138/7138 [==============================] - 5s 637us/sample - loss: 0.0059 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0064
# Epoch 10/1000
# 7138/7138 [==============================] - 5s 644us/sample - loss: 0.0059 - last_time_step_mse: 0.0056 - val_loss: 0.0059 - val_last_time_step_mse: 0.0057
# Epoch 11/1000
# 7138/7138 [==============================] - 5s 646us/sample - loss: 0.0059 - last_time_step_mse: 0.0055 - val_loss: 0.0059 - val_last_time_step_mse: 0.0059
# Epoch 12/1000
# 7138/7138 [==============================] - 5s 657us/sample - loss: 0.0058 - last_time_step_mse: 0.0055 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 13/1000
# 7138/7138 [==============================] - 5s 666us/sample - loss: 0.0058 - last_time_step_mse: 0.0055 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 14/1000
# 7138/7138 [==============================] - 5s 659us/sample - loss: 0.0058 - last_time_step_mse: 0.0054 - val_loss: 0.0057 - val_last_time_step_mse: 0.0056
# Epoch 15/1000
# 7138/7138 [==============================] - 5s 642us/sample - loss: 0.0057 - last_time_step_mse: 0.0053 - val_loss: 0.0057 - val_last_time_step_mse: 0.0055
# Epoch 16/1000
# 7138/7138 [==============================] - 4s 628us/sample - loss: 0.0057 - last_time_step_mse: 0.0053 - val_loss: 0.0056 - val_last_time_step_mse: 0.0053
# Epoch 17/1000
# 7138/7138 [==============================] - 5s 643us/sample - loss: 0.0057 - last_time_step_mse: 0.0053 - val_loss: 0.0066 - val_last_time_step_mse: 0.0062
# Epoch 18/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0057 - last_time_step_mse: 0.0053 - val_loss: 0.0057 - val_last_time_step_mse: 0.0056
# Epoch 19/1000
# 7138/7138 [==============================] - 5s 633us/sample - loss: 0.0057 - last_time_step_mse: 0.0054 - val_loss: 0.0056 - val_last_time_step_mse: 0.0053
# Epoch 20/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0056 - last_time_step_mse: 0.0052 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 21/1000
# 7138/7138 [==============================] - 5s 637us/sample - loss: 0.0056 - last_time_step_mse: 0.0052 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 22/1000
# 7138/7138 [==============================] - 5s 634us/sample - loss: 0.0056 - last_time_step_mse: 0.0052 - val_loss: 0.0055 - val_last_time_step_mse: 0.0052
# Epoch 23/1000
# 7138/7138 [==============================] - 5s 633us/sample - loss: 0.0056 - last_time_step_mse: 0.0051 - val_loss: 0.0056 - val_last_time_step_mse: 0.0053
# Epoch 24/1000
# 7138/7138 [==============================] - 5s 641us/sample - loss: 0.0055 - last_time_step_mse: 0.0051 - val_loss: 0.0059 - val_last_time_step_mse: 0.0058
# Epoch 25/1000
# 7138/7138 [==============================] - 5s 655us/sample - loss: 0.0055 - last_time_step_mse: 0.0051 - val_loss: 0.0061 - val_last_time_step_mse: 0.0060
# Epoch 26/1000
# 7138/7138 [==============================] - 5s 646us/sample - loss: 0.0055 - last_time_step_mse: 0.0051 - val_loss: 0.0056 - val_last_time_step_mse: 0.0054
# Epoch 27/1000
# 7138/7138 [==============================] - 5s 661us/sample - loss: 0.0055 - last_time_step_mse: 0.0051 - val_loss: 0.0062 - val_last_time_step_mse: 0.0061
# Epoch 28/1000
# 7138/7138 [==============================] - 5s 661us/sample - loss: 0.0055 - last_time_step_mse: 0.0050 - val_loss: 0.0056 - val_last_time_step_mse: 0.0052
# Epoch 29/1000
# 7138/7138 [==============================] - 5s 678us/sample - loss: 0.0055 - last_time_step_mse: 0.0050 - val_loss: 0.0056 - val_last_time_step_mse: 0.0052
# Epoch 30/1000
# 7138/7138 [==============================] - 5s 672us/sample - loss: 0.0055 - last_time_step_mse: 0.0050 - val_loss: 0.0055 - val_last_time_step_mse: 0.0052
# Epoch 31/1000
# 7138/7138 [==============================] - 5s 665us/sample - loss: 0.0055 - last_time_step_mse: 0.0050 - val_loss: 0.0055 - val_last_time_step_mse: 0.0051
# Epoch 32/1000
# 7138/7138 [==============================] - 5s 667us/sample - loss: 0.0055 - last_time_step_mse: 0.0050 - val_loss: 0.0054 - val_last_time_step_mse: 0.0050
# Epoch 33/1000
# 7138/7138 [==============================] - 5s 660us/sample - loss: 0.0054 - last_time_step_mse: 0.0049 - val_loss: 0.0056 - val_last_time_step_mse: 0.0051
# Epoch 34/1000
# 7138/7138 [==============================] - 5s 670us/sample - loss: 0.0055 - last_time_step_mse: 0.0050 - val_loss: 0.0057 - val_last_time_step_mse: 0.0056
# Epoch 35/1000
# 7138/7138 [==============================] - 5s 664us/sample - loss: 0.0054 - last_time_step_mse: 0.0049 - val_loss: 0.0055 - val_last_time_step_mse: 0.0050
# Epoch 36/1000
# 7138/7138 [==============================] - 5s 654us/sample - loss: 0.0054 - last_time_step_mse: 0.0049 - val_loss: 0.0059 - val_last_time_step_mse: 0.0055
# Epoch 37/1000
# 7138/7138 [==============================] - 5s 656us/sample - loss: 0.0054 - last_time_step_mse: 0.0049 - val_loss: 0.0054 - val_last_time_step_mse: 0.0051
# Epoch 38/1000
# 7138/7138 [==============================] - 5s 656us/sample - loss: 0.0054 - last_time_step_mse: 0.0048 - val_loss: 0.0054 - val_last_time_step_mse: 0.0050
# Epoch 39/1000
# 7138/7138 [==============================] - 5s 654us/sample - loss: 0.0054 - last_time_step_mse: 0.0049 - val_loss: 0.0053 - val_last_time_step_mse: 0.0050
# Epoch 40/1000
# 7138/7138 [==============================] - 5s 654us/sample - loss: 0.0054 - last_time_step_mse: 0.0049 - val_loss: 0.0053 - val_last_time_step_mse: 0.0049
# Epoch 41/1000
# 7138/7138 [==============================] - 5s 665us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0054 - val_last_time_step_mse: 0.0050
# Epoch 42/1000
# 7138/7138 [==============================] - 5s 674us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0055 - val_last_time_step_mse: 0.0051
# Epoch 43/1000
# 7138/7138 [==============================] - 5s 670us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0054 - val_last_time_step_mse: 0.0050
# Epoch 44/1000
# 7138/7138 [==============================] - 5s 694us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0053 - val_last_time_step_mse: 0.0050
# Epoch 45/1000
# 7138/7138 [==============================] - 5s 694us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0059 - val_last_time_step_mse: 0.0055
# Epoch 46/1000
# 7138/7138 [==============================] - 5s 669us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0053 - val_last_time_step_mse: 0.0050
# Epoch 47/1000
# 7138/7138 [==============================] - 5s 652us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0053 - val_last_time_step_mse: 0.0050
# Epoch 48/1000
# 7138/7138 [==============================] - 5s 640us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0053 - val_last_time_step_mse: 0.0049
# Epoch 49/1000
# 7138/7138 [==============================] - 5s 665us/sample - loss: 0.0053 - last_time_step_mse: 0.0047 - val_loss: 0.0059 - val_last_time_step_mse: 0.0057
# Epoch 50/1000
# 7138/7138 [==============================] - 5s 675us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0053 - val_last_time_step_mse: 0.0051
# Epoch 51/1000
# 7138/7138 [==============================] - 5s 677us/sample - loss: 0.0053 - last_time_step_mse: 0.0048 - val_loss: 0.0053 - val_last_time_step_mse: 0.0050
# Epoch 52/1000
# 7138/7138 [==============================] - 5s 672us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 53/1000
# 7138/7138 [==============================] - 5s 678us/sample - loss: 0.0053 - last_time_step_mse: 0.0047 - val_loss: 0.0054 - val_last_time_step_mse: 0.0050
# Epoch 54/1000
# 7138/7138 [==============================] - 5s 695us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 55/1000
# 7138/7138 [==============================] - 5s 674us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0054 - val_last_time_step_mse: 0.0051
# Epoch 56/1000
# 7138/7138 [==============================] - 5s 676us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0053 - val_last_time_step_mse: 0.0049
# Epoch 57/1000
# 7138/7138 [==============================] - 5s 674us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0055 - val_last_time_step_mse: 0.0049
# Epoch 58/1000
# 7138/7138 [==============================] - 5s 677us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0055 - val_last_time_step_mse: 0.0051
# Epoch 59/1000
# 7138/7138 [==============================] - 5s 675us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 60/1000
# 7138/7138 [==============================] - 5s 670us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0058 - val_last_time_step_mse: 0.0053
# Epoch 61/1000
# 7138/7138 [==============================] - 5s 672us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0055 - val_last_time_step_mse: 0.0051
# Epoch 62/1000
# 7138/7138 [==============================] - 5s 721us/sample - loss: 0.0052 - last_time_step_mse: 0.0047 - val_loss: 0.0052 - val_last_time_step_mse: 0.0049
# Epoch 63/1000
# 7138/7138 [==============================] - 5s 706us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 64/1000
# 7138/7138 [==============================] - 5s 670us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0056 - val_last_time_step_mse: 0.0051
# Epoch 65/1000
# 7138/7138 [==============================] - 5s 671us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0053 - val_last_time_step_mse: 0.0050
# Epoch 66/1000
# 7138/7138 [==============================] - 5s 686us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0053 - val_last_time_step_mse: 0.0049
# Epoch 67/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0051 - last_time_step_mse: 0.0046 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 68/1000
# 7138/7138 [==============================] - 5s 684us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 69/1000
# 7138/7138 [==============================] - 5s 689us/sample - loss: 0.0051 - last_time_step_mse: 0.0046 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 70/1000
# 7138/7138 [==============================] - 5s 676us/sample - loss: 0.0051 - last_time_step_mse: 0.0046 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 71/1000
# 7138/7138 [==============================] - 5s 675us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 72/1000
# 7138/7138 [==============================] - 5s 677us/sample - loss: 0.0052 - last_time_step_mse: 0.0046 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 73/1000
# 7138/7138 [==============================] - 5s 679us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 74/1000
# 7138/7138 [==============================] - 5s 678us/sample - loss: 0.0051 - last_time_step_mse: 0.0046 - val_loss: 0.0054 - val_last_time_step_mse: 0.0049
# Epoch 75/1000
# 7138/7138 [==============================] - 5s 686us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 76/1000
# 7138/7138 [==============================] - 5s 676us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 77/1000
# 7138/7138 [==============================] - 5s 690us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 78/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0051 - last_time_step_mse: 0.0046 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 79/1000
# 7138/7138 [==============================] - 5s 695us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 80/1000
# 7138/7138 [==============================] - 5s 668us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 81/1000
# 7138/7138 [==============================] - 5s 657us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 82/1000
# 7138/7138 [==============================] - 5s 655us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0054 - val_last_time_step_mse: 0.0049
# Epoch 83/1000
# 7138/7138 [==============================] - 5s 653us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 84/1000
# 7138/7138 [==============================] - 5s 673us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 85/1000
# 7138/7138 [==============================] - 5s 686us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 86/1000
# 7138/7138 [==============================] - 5s 677us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 87/1000
# 7138/7138 [==============================] - 5s 685us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 88/1000
# 7138/7138 [==============================] - 5s 669us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 89/1000
# 7138/7138 [==============================] - 5s 646us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 90/1000
# 7138/7138 [==============================] - 5s 651us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0055 - val_last_time_step_mse: 0.0050
# Epoch 91/1000
# 7138/7138 [==============================] - 5s 650us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0050 - val_last_time_step_mse: 0.0046
# Epoch 92/1000
# 7138/7138 [==============================] - 5s 649us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 93/1000
# 7138/7138 [==============================] - 5s 651us/sample - loss: 0.0051 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0048
# Epoch 94/1000
# 7138/7138 [==============================] - 5s 679us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 95/1000
# 7138/7138 [==============================] - 5s 667us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 96/1000
# 7138/7138 [==============================] - 5s 681us/sample - loss: 0.0051 - last_time_step_mse: 0.0045 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 97/1000
# 7138/7138 [==============================] - 5s 679us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 98/1000
# 7138/7138 [==============================] - 5s 674us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0053 - val_last_time_step_mse: 0.0048
# Epoch 99/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 100/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 101/1000
# 7138/7138 [==============================] - 5s 681us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 102/1000
# 7138/7138 [==============================] - 5s 687us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 103/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 104/1000
# 7138/7138 [==============================] - 5s 688us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 105/1000
# 7138/7138 [==============================] - 5s 683us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 106/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 107/1000
# 7138/7138 [==============================] - 5s 686us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 108/1000
# 7138/7138 [==============================] - 5s 714us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 109/1000
# 7138/7138 [==============================] - 5s 688us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0055 - val_last_time_step_mse: 0.0052
# Epoch 110/1000
# 7138/7138 [==============================] - 5s 676us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0053 - val_last_time_step_mse: 0.0048
# Epoch 111/1000
# 7138/7138 [==============================] - 5s 690us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 112/1000
# 7138/7138 [==============================] - 5s 688us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 113/1000
# 7138/7138 [==============================] - 5s 688us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 114/1000
# 7138/7138 [==============================] - 5s 684us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 115/1000
# 7138/7138 [==============================] - 5s 698us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 116/1000
# 7138/7138 [==============================] - 5s 705us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 117/1000
# 7138/7138 [==============================] - 5s 696us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0051 - val_last_time_step_mse: 0.0047
# Epoch 118/1000
# 7138/7138 [==============================] - 5s 683us/sample - loss: 0.0050 - last_time_step_mse: 0.0044 - val_loss: 0.0049 - val_last_time_step_mse: 0.0044
# Epoch 119/1000
# 7138/7138 [==============================] - 5s 687us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0052 - val_last_time_step_mse: 0.0047
# Epoch 120/1000
# 7138/7138 [==============================] - 5s 686us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 121/1000
# 7138/7138 [==============================] - 5s 686us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 122/1000
# 7138/7138 [==============================] - 5s 679us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0052 - val_last_time_step_mse: 0.0048
# Epoch 123/1000
# 7138/7138 [==============================] - 5s 682us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 124/1000
# 7138/7138 [==============================] - 5s 680us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0044
# Epoch 125/1000
# 7138/7138 [==============================] - 5s 696us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 126/1000
# 7138/7138 [==============================] - 5s 723us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 127/1000
# 7138/7138 [==============================] - 5s 712us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 128/1000
# 7138/7138 [==============================] - 5s 681us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 129/1000
# 7138/7138 [==============================] - 5s 685us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 130/1000
# 7138/7138 [==============================] - 5s 689us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 131/1000
# 7138/7138 [==============================] - 5s 679us/sample - loss: 0.0050 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0044
# Epoch 132/1000
# 7138/7138 [==============================] - 5s 646us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 133/1000
# 7138/7138 [==============================] - 5s 664us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 134/1000
# 7138/7138 [==============================] - 5s 654us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0044
# Epoch 135/1000
# 7138/7138 [==============================] - 5s 651us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 136/1000
# 7138/7138 [==============================] - 5s 693us/sample - loss: 0.0049 - last_time_step_mse: 0.0042 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 137/1000
# 7138/7138 [==============================] - 5s 660us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 138/1000
# 7138/7138 [==============================] - 5s 696us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 139/1000
# 7138/7138 [==============================] - 5s 700us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 140/1000
# 7138/7138 [==============================] - 5s 695us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0051 - val_last_time_step_mse: 0.0046
# Epoch 141/1000
# 7138/7138 [==============================] - 5s 690us/sample - loss: 0.0049 - last_time_step_mse: 0.0042 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 142/1000
# 7138/7138 [==============================] - 5s 683us/sample - loss: 0.0049 - last_time_step_mse: 0.0042 - val_loss: 0.0049 - val_last_time_step_mse: 0.0044
# Epoch 143/1000
# 7138/7138 [==============================] - 5s 683us/sample - loss: 0.0049 - last_time_step_mse: 0.0042 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 144/1000
# 7138/7138 [==============================] - 5s 683us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0057 - val_last_time_step_mse: 0.0051
# Epoch 145/1000
# 7138/7138 [==============================] - 5s 678us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 146/1000
# 7138/7138 [==============================] - 5s 681us/sample - loss: 0.0049 - last_time_step_mse: 0.0042 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 147/1000
# 7138/7138 [==============================] - 5s 696us/sample - loss: 0.0049 - last_time_step_mse: 0.0043 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# (10, 1)
# (10, 1)
# (10,)
