# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1015_north.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o[177:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)
flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)

#TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_test.shape)
print(X_test[-1:].shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

#DEFINE AND COMPILE MODEL
model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(forecast))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("gru_1014_north.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MIN FORECAST
#flow
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time (in 5 minutes intervals)")
    plt.ylabel('Volume (veh/h)')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (1020, 50, 1)
# (1, 50, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7137 samples, validate on 2040 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0362 - last_time_step_mse: 0.0322 - val_loss: 0.0140 - val_last_time_step_mse: 0.0121
# Epoch 2/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0129 - last_time_step_mse: 0.0112 - val_loss: 0.0122 - val_last_time_step_mse: 0.0115
# Epoch 3/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0117 - last_time_step_mse: 0.0109 - val_loss: 0.0115 - val_last_time_step_mse: 0.0113
# Epoch 4/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0112 - last_time_step_mse: 0.0108 - val_loss: 0.0111 - val_last_time_step_mse: 0.0111
# Epoch 5/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0109 - last_time_step_mse: 0.0107 - val_loss: 0.0109 - val_last_time_step_mse: 0.0110
# Epoch 6/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0108 - last_time_step_mse: 0.0106 - val_loss: 0.0109 - val_last_time_step_mse: 0.0110
# Epoch 7/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0108 - last_time_step_mse: 0.0106 - val_loss: 0.0108 - val_last_time_step_mse: 0.0109
# Epoch 8/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0107 - last_time_step_mse: 0.0106 - val_loss: 0.0107 - val_last_time_step_mse: 0.0109
# Epoch 9/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0106 - last_time_step_mse: 0.0105 - val_loss: 0.0106 - val_last_time_step_mse: 0.0107
# Epoch 10/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0105 - last_time_step_mse: 0.0104 - val_loss: 0.0105 - val_last_time_step_mse: 0.0105
# Epoch 11/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0104 - last_time_step_mse: 0.0102 - val_loss: 0.0102 - val_last_time_step_mse: 0.0102
# Epoch 12/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0102 - last_time_step_mse: 0.0099 - val_loss: 0.0102 - val_last_time_step_mse: 0.0102
# Epoch 13/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0101 - last_time_step_mse: 0.0098 - val_loss: 0.0102 - val_last_time_step_mse: 0.0101
# Epoch 14/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0101 - last_time_step_mse: 0.0098 - val_loss: 0.0100 - val_last_time_step_mse: 0.0099
# Epoch 15/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0100 - last_time_step_mse: 0.0098 - val_loss: 0.0103 - val_last_time_step_mse: 0.0103
# Epoch 16/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0100 - last_time_step_mse: 0.0097 - val_loss: 0.0098 - val_last_time_step_mse: 0.0098
# Epoch 17/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0099 - last_time_step_mse: 0.0096 - val_loss: 0.0101 - val_last_time_step_mse: 0.0100
# Epoch 18/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0098 - last_time_step_mse: 0.0096 - val_loss: 0.0097 - val_last_time_step_mse: 0.0096
# Epoch 19/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0098 - last_time_step_mse: 0.0095 - val_loss: 0.0100 - val_last_time_step_mse: 0.0099
# Epoch 20/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0097 - last_time_step_mse: 0.0094 - val_loss: 0.0097 - val_last_time_step_mse: 0.0096
# Epoch 21/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0096 - last_time_step_mse: 0.0093 - val_loss: 0.0095 - val_last_time_step_mse: 0.0094
# Epoch 22/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0095 - last_time_step_mse: 0.0092 - val_loss: 0.0095 - val_last_time_step_mse: 0.0093
# Epoch 23/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0092 - last_time_step_mse: 0.0089 - val_loss: 0.0091 - val_last_time_step_mse: 0.0088
# Epoch 24/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0088 - last_time_step_mse: 0.0084 - val_loss: 0.0089 - val_last_time_step_mse: 0.0083
# Epoch 25/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0085 - last_time_step_mse: 0.0079 - val_loss: 0.0082 - val_last_time_step_mse: 0.0074
# Epoch 26/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0082 - last_time_step_mse: 0.0076 - val_loss: 0.0092 - val_last_time_step_mse: 0.0085
# Epoch 27/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0081 - last_time_step_mse: 0.0074 - val_loss: 0.0080 - val_last_time_step_mse: 0.0071
# Epoch 28/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0080 - last_time_step_mse: 0.0072 - val_loss: 0.0080 - val_last_time_step_mse: 0.0072
# Epoch 29/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0079 - last_time_step_mse: 0.0072 - val_loss: 0.0079 - val_last_time_step_mse: 0.0071
# Epoch 30/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0078 - last_time_step_mse: 0.0071 - val_loss: 0.0078 - val_last_time_step_mse: 0.0070
# Epoch 31/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0078 - last_time_step_mse: 0.0070 - val_loss: 0.0078 - val_last_time_step_mse: 0.0069
# Epoch 32/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0078 - last_time_step_mse: 0.0071 - val_loss: 0.0078 - val_last_time_step_mse: 0.0069
# Epoch 33/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0077 - last_time_step_mse: 0.0069 - val_loss: 0.0077 - val_last_time_step_mse: 0.0068
# Epoch 34/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0076 - last_time_step_mse: 0.0069 - val_loss: 0.0075 - val_last_time_step_mse: 0.0066
# Epoch 35/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0076 - last_time_step_mse: 0.0068 - val_loss: 0.0075 - val_last_time_step_mse: 0.0066
# Epoch 36/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0076 - last_time_step_mse: 0.0067 - val_loss: 0.0075 - val_last_time_step_mse: 0.0065
# Epoch 37/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0075 - last_time_step_mse: 0.0067 - val_loss: 0.0074 - val_last_time_step_mse: 0.0066
# Epoch 38/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0075 - last_time_step_mse: 0.0067 - val_loss: 0.0074 - val_last_time_step_mse: 0.0065
# Epoch 39/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0075 - last_time_step_mse: 0.0066 - val_loss: 0.0074 - val_last_time_step_mse: 0.0065
# Epoch 40/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0074 - last_time_step_mse: 0.0066 - val_loss: 0.0074 - val_last_time_step_mse: 0.0065
# Epoch 41/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0074 - last_time_step_mse: 0.0066 - val_loss: 0.0074 - val_last_time_step_mse: 0.0065
# Epoch 42/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0074 - last_time_step_mse: 0.0065 - val_loss: 0.0073 - val_last_time_step_mse: 0.0065
# Epoch 43/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0074 - last_time_step_mse: 0.0065 - val_loss: 0.0074 - val_last_time_step_mse: 0.0065
# Epoch 44/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0074 - last_time_step_mse: 0.0065 - val_loss: 0.0072 - val_last_time_step_mse: 0.0063
# Epoch 45/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0073 - last_time_step_mse: 0.0065 - val_loss: 0.0073 - val_last_time_step_mse: 0.0064
# Epoch 46/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0073 - last_time_step_mse: 0.0064 - val_loss: 0.0072 - val_last_time_step_mse: 0.0063
# Epoch 47/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0073 - last_time_step_mse: 0.0064 - val_loss: 0.0072 - val_last_time_step_mse: 0.0063
# Epoch 48/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0073 - last_time_step_mse: 0.0064 - val_loss: 0.0072 - val_last_time_step_mse: 0.0063
# Epoch 49/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0072 - last_time_step_mse: 0.0063 - val_loss: 0.0072 - val_last_time_step_mse: 0.0063
# Epoch 50/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0072 - last_time_step_mse: 0.0063 - val_loss: 0.0073 - val_last_time_step_mse: 0.0063
# Epoch 51/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0072 - last_time_step_mse: 0.0063 - val_loss: 0.0073 - val_last_time_step_mse: 0.0064
# Epoch 52/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0072 - last_time_step_mse: 0.0062 - val_loss: 0.0071 - val_last_time_step_mse: 0.0062
# Epoch 53/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0072 - last_time_step_mse: 0.0062 - val_loss: 0.0072 - val_last_time_step_mse: 0.0062
# Epoch 54/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0072 - last_time_step_mse: 0.0062 - val_loss: 0.0071 - val_last_time_step_mse: 0.0062
# Epoch 55/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0062 - val_loss: 0.0073 - val_last_time_step_mse: 0.0063
# Epoch 56/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0062 - val_loss: 0.0072 - val_last_time_step_mse: 0.0062
# Epoch 57/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0072 - val_last_time_step_mse: 0.0062
# Epoch 58/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0070 - val_last_time_step_mse: 0.0061
# Epoch 59/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 60/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0071 - val_last_time_step_mse: 0.0061
# Epoch 61/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0071 - val_last_time_step_mse: 0.0061
# Epoch 62/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0070 - val_last_time_step_mse: 0.0061
# Epoch 63/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 64/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 65/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0072 - val_last_time_step_mse: 0.0061
# Epoch 66/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0060 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 67/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0072 - val_last_time_step_mse: 0.0063
# Epoch 68/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0071 - last_time_step_mse: 0.0061 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 69/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0069 - val_last_time_step_mse: 0.0059
# Epoch 70/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0071 - val_last_time_step_mse: 0.0061
# Epoch 71/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0060 - val_loss: 0.0069 - val_last_time_step_mse: 0.0059
# Epoch 72/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0059 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 73/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0059 - val_loss: 0.0070 - val_last_time_step_mse: 0.0059
# Epoch 74/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0059
# Epoch 75/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0070 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0059
# Epoch 76/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0060
# Epoch 77/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 78/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0060
# Epoch 79/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0059 - val_loss: 0.0070 - val_last_time_step_mse: 0.0059
# Epoch 80/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0059 - val_loss: 0.0071 - val_last_time_step_mse: 0.0060
# Epoch 81/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0070 - val_last_time_step_mse: 0.0059
# Epoch 82/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 83/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0059
# Epoch 84/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0068 - val_last_time_step_mse: 0.0058
# Epoch 85/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0068 - val_last_time_step_mse: 0.0059
# Epoch 86/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 87/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0071 - val_last_time_step_mse: 0.0061
# Epoch 88/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0068 - val_last_time_step_mse: 0.0058
# Epoch 89/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0070 - val_last_time_step_mse: 0.0059
# Epoch 90/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 91/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 92/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 93/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 94/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 95/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0071 - val_last_time_step_mse: 0.0061
# Epoch 96/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0069 - last_time_step_mse: 0.0058 - val_loss: 0.0070 - val_last_time_step_mse: 0.0060
# Epoch 97/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0058 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 98/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0058 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 99/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 100/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0058
# Epoch 101/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0058
# Epoch 102/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 103/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0067 - val_last_time_step_mse: 0.0057
# Epoch 104/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 105/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 106/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0067 - val_last_time_step_mse: 0.0057
# Epoch 107/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0056
# Epoch 108/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0058
# Epoch 109/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0057
# Epoch 110/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 111/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0057
# Epoch 112/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 113/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0067 - val_last_time_step_mse: 0.0056
# Epoch 114/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0057 - val_loss: 0.0067 - val_last_time_step_mse: 0.0056
# Epoch 115/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0056 - val_loss: 0.0068 - val_last_time_step_mse: 0.0058
# Epoch 116/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0056
# Epoch 117/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0056
# Epoch 118/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0056
# Epoch 119/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0068 - val_last_time_step_mse: 0.0057
# Epoch 120/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0056
# Epoch 121/700
# 7137/7137 [==============================] - 11s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0068 - val_last_time_step_mse: 0.0056
# Epoch 122/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0068 - last_time_step_mse: 0.0056 - val_loss: 0.0069 - val_last_time_step_mse: 0.0058
# Epoch 123/700
# 7137/7137 [==============================] - 12s 2ms/sample - loss: 0.0067 - last_time_step_mse: 0.0056 - val_loss: 0.0067 - val_last_time_step_mse: 0.0057
# (10, 1)
# (10, 1)
# (10,)
