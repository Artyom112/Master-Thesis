# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1015_west.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)

flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
#TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_test.shape)
print(X_test[-1:].shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

#MODEL
def last_time_step_mse(Y_true, Y_pred):
     return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=1000,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("vawenet_1015_west.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MIN FORECAST
#50 MIN FORECAST
#flow
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time (in 5 minutes intervals)")
    plt.ylabel('Volume (veh/h)')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (1072, 50, 1)
# (1, 50, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7499 samples, validate on 2142 samples
# Epoch 1/1000
# 7499/7499 [==============================] - 5s 697us/sample - loss: 0.0176 - last_time_step_mse: 0.0153 - val_loss: 0.0029 - val_last_time_step_mse: 0.0028
# Epoch 2/1000
# 7499/7499 [==============================] - 5s 643us/sample - loss: 0.0028 - last_time_step_mse: 0.0026 - val_loss: 0.0026 - val_last_time_step_mse: 0.0025
# Epoch 3/1000
# 7499/7499 [==============================] - 5s 640us/sample - loss: 0.0026 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0025
# Epoch 4/1000
# 7499/7499 [==============================] - 5s 645us/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0024 - val_last_time_step_mse: 0.0023
# Epoch 5/1000
# 7499/7499 [==============================] - 5s 646us/sample - loss: 0.0024 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0024
# Epoch 6/1000
# 7499/7499 [==============================] - 5s 671us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0023
# Epoch 7/1000
# 7499/7499 [==============================] - 5s 665us/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0023 - val_last_time_step_mse: 0.0023
# Epoch 8/1000
# 7499/7499 [==============================] - 5s 673us/sample - loss: 0.0023 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0023
# Epoch 9/1000
# 7499/7499 [==============================] - 5s 671us/sample - loss: 0.0023 - last_time_step_mse: 0.0022 - val_loss: 0.0023 - val_last_time_step_mse: 0.0022
# Epoch 10/1000
# 7499/7499 [==============================] - 5s 660us/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0023
# Epoch 11/1000
# 7499/7499 [==============================] - 5s 659us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0022
# Epoch 12/1000
# 7499/7499 [==============================] - 5s 639us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 13/1000
# 7499/7499 [==============================] - 5s 639us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 14/1000
# 7499/7499 [==============================] - 5s 666us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0022 - val_last_time_step_mse: 0.0022
# Epoch 15/1000
# 7499/7499 [==============================] - 5s 685us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 16/1000
# 7499/7499 [==============================] - 5s 652us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 17/1000
# 7499/7499 [==============================] - 5s 661us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 18/1000
# 7499/7499 [==============================] - 5s 669us/sample - loss: 0.0022 - last_time_step_mse: 0.0021 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 19/1000
# 7499/7499 [==============================] - 5s 666us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 20/1000
# 7499/7499 [==============================] - 5s 665us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0021
# Epoch 21/1000
# 7499/7499 [==============================] - 5s 655us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 22/1000
# 7499/7499 [==============================] - 5s 652us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0021
# Epoch 23/1000
# 7499/7499 [==============================] - 5s 660us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0021
# Epoch 24/1000
# 7499/7499 [==============================] - 5s 668us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0021
# Epoch 25/1000
# 7499/7499 [==============================] - 5s 673us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 26/1000
# 7499/7499 [==============================] - 5s 669us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 27/1000
# 7499/7499 [==============================] - 5s 670us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 28/1000
# 7499/7499 [==============================] - 5s 669us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 29/1000
# 7499/7499 [==============================] - 5s 687us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 30/1000
# 7499/7499 [==============================] - 5s 679us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0020 - val_last_time_step_mse: 0.0020
# Epoch 31/1000
# 7499/7499 [==============================] - 5s 679us/sample - loss: 0.0021 - last_time_step_mse: 0.0020 - val_loss: 0.0020 - val_last_time_step_mse: 0.0020
# Epoch 32/1000
# 7499/7499 [==============================] - 5s 678us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 33/1000
# 7499/7499 [==============================] - 5s 679us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0020
# Epoch 34/1000
# 7499/7499 [==============================] - 5s 663us/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 35/1000
# 7499/7499 [==============================] - 5s 643us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 36/1000
# 7499/7499 [==============================] - 5s 643us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 37/1000
# 7499/7499 [==============================] - 5s 657us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0021
# Epoch 38/1000
# 7499/7499 [==============================] - 5s 677us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0020
# Epoch 39/1000
# 7499/7499 [==============================] - 5s 643us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 40/1000
# 7499/7499 [==============================] - 5s 641us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 41/1000
# 7499/7499 [==============================] - 5s 642us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 42/1000
# 7499/7499 [==============================] - 5s 636us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 43/1000
# 7499/7499 [==============================] - 5s 652us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 44/1000
# 7499/7499 [==============================] - 5s 641us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 45/1000
# 7499/7499 [==============================] - 5s 648us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 46/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0021
# Epoch 47/1000
# 7499/7499 [==============================] - 5s 694us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 48/1000
# 7499/7499 [==============================] - 5s 669us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 49/1000
# 7499/7499 [==============================] - 5s 654us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 50/1000
# 7499/7499 [==============================] - 5s 654us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 51/1000
# 7499/7499 [==============================] - 5s 676us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0020
# Epoch 52/1000
# 7499/7499 [==============================] - 5s 662us/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 53/1000
# 7499/7499 [==============================] - 5s 652us/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 54/1000
# 7499/7499 [==============================] - 5s 659us/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 55/1000
# 7499/7499 [==============================] - 5s 657us/sample - loss: 0.0020 - last_time_step_mse: 0.0019 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 56/1000
# 7499/7499 [==============================] - 5s 655us/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 57/1000
# 7499/7499 [==============================] - 5s 663us/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 58/1000
# 7499/7499 [==============================] - 5s 664us/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 59/1000
# 7499/7499 [==============================] - 5s 659us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 60/1000
# 7499/7499 [==============================] - 5s 655us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 61/1000
# 7499/7499 [==============================] - 5s 663us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 62/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 63/1000
# 7499/7499 [==============================] - 5s 664us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 64/1000
# 7499/7499 [==============================] - 5s 653us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 65/1000
# 7499/7499 [==============================] - 5s 655us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 66/1000
# 7499/7499 [==============================] - 5s 659us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 67/1000
# 7499/7499 [==============================] - 5s 670us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 68/1000
# 7499/7499 [==============================] - 5s 658us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 69/1000
# 7499/7499 [==============================] - 5s 659us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 70/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 71/1000
# 7499/7499 [==============================] - 5s 658us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 72/1000
# 7499/7499 [==============================] - 5s 662us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 73/1000
# 7499/7499 [==============================] - 5s 662us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 74/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 75/1000
# 7499/7499 [==============================] - 5s 666us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 76/1000
# 7499/7499 [==============================] - 5s 660us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 77/1000
# 7499/7499 [==============================] - 5s 666us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 78/1000
# 7499/7499 [==============================] - 5s 662us/sample - loss: 0.0019 - last_time_step_mse: 0.0018 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 79/1000
# 7499/7499 [==============================] - 5s 676us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 80/1000
# 7499/7499 [==============================] - 5s 680us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 81/1000
# 7499/7499 [==============================] - 5s 680us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 82/1000
# 7499/7499 [==============================] - 5s 684us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 83/1000
# 7499/7499 [==============================] - 5s 668us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 84/1000
# 7499/7499 [==============================] - 5s 691us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 85/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 86/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 87/1000
# 7499/7499 [==============================] - 5s 709us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 88/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 89/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 90/1000
# 7499/7499 [==============================] - 5s 700us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 91/1000
# 7499/7499 [==============================] - 5s 708us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 92/1000
# 7499/7499 [==============================] - 5s 706us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 93/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 94/1000
# 7499/7499 [==============================] - 5s 709us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 95/1000
# 7499/7499 [==============================] - 5s 684us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 96/1000
# 7499/7499 [==============================] - 5s 671us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 97/1000
# 7499/7499 [==============================] - 5s 668us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 98/1000
# 7499/7499 [==============================] - 5s 697us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 99/1000
# 7499/7499 [==============================] - 5s 711us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 100/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 101/1000
# 7499/7499 [==============================] - 5s 685us/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 102/1000
# 7499/7499 [==============================] - 5s 683us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 103/1000
# 7499/7499 [==============================] - 5s 679us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 104/1000
# 7499/7499 [==============================] - 5s 688us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 105/1000
# 7499/7499 [==============================] - 5s 694us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 106/1000
# 7499/7499 [==============================] - 5s 689us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 107/1000
# 7499/7499 [==============================] - 5s 688us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 108/1000
# 7499/7499 [==============================] - 6s 741us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 109/1000
# 7499/7499 [==============================] - 6s 734us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 110/1000
# 7499/7499 [==============================] - 5s 697us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 111/1000
# 7499/7499 [==============================] - 5s 692us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 112/1000
# 7499/7499 [==============================] - 5s 695us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 113/1000
# 7499/7499 [==============================] - 5s 689us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 114/1000
# 7499/7499 [==============================] - 5s 688us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 115/1000
# 7499/7499 [==============================] - 5s 684us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 116/1000
# 7499/7499 [==============================] - 5s 691us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 117/1000
# 7499/7499 [==============================] - 5s 692us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 118/1000
# 7499/7499 [==============================] - 5s 691us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 119/1000
# 7499/7499 [==============================] - 5s 690us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 120/1000
# 7499/7499 [==============================] - 5s 692us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 121/1000
# 7499/7499 [==============================] - 5s 690us/sample - loss: 0.0018 - last_time_step_mse: 0.0017 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 122/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 123/1000
# 7499/7499 [==============================] - 5s 692us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 124/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 125/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 126/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 127/1000
# 7499/7499 [==============================] - 5s 704us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 128/1000
# 7499/7499 [==============================] - 5s 706us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 129/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 130/1000
# 7499/7499 [==============================] - 5s 704us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 131/1000
# 7499/7499 [==============================] - 5s 708us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 132/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 133/1000
# 7499/7499 [==============================] - 5s 706us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 134/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 135/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 136/1000
# 7499/7499 [==============================] - 5s 695us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 137/1000
# 7499/7499 [==============================] - 5s 695us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 138/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 139/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 140/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 141/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 142/1000
# 7499/7499 [==============================] - 5s 695us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 143/1000
# 7499/7499 [==============================] - 5s 697us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 144/1000
# 7499/7499 [==============================] - 5s 716us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0017 - val_last_time_step_mse: 0.0016
# Epoch 145/1000
# 7499/7499 [==============================] - 5s 702us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 146/1000
# 7499/7499 [==============================] - 5s 697us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 147/1000
# 7499/7499 [==============================] - 5s 700us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 148/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 149/1000
# 7499/7499 [==============================] - 5s 704us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 150/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 151/1000
# 7499/7499 [==============================] - 5s 711us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 152/1000
# 7499/7499 [==============================] - 5s 715us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 153/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0018 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 154/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0018 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 155/1000
# 7499/7499 [==============================] - 5s 700us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 156/1000
# 7499/7499 [==============================] - 5s 706us/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 157/1000
# 7499/7499 [==============================] - 6s 757us/sample - loss: 0.0018 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0016
# Epoch 158/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 159/1000
# 7499/7499 [==============================] - 5s 679us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 160/1000
# 7499/7499 [==============================] - 5s 664us/sample - loss: 0.0018 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 161/1000
# 7499/7499 [==============================] - 5s 666us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0016
# Epoch 162/1000
# 7499/7499 [==============================] - 5s 671us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 163/1000
# 7499/7499 [==============================] - 5s 671us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 164/1000
# 7499/7499 [==============================] - 5s 666us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 165/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 166/1000
# 7499/7499 [==============================] - 5s 667us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 167/1000
# 7499/7499 [==============================] - 5s 707us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 168/1000
# 7499/7499 [==============================] - 6s 800us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 169/1000
# 7499/7499 [==============================] - 5s 727us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0016
# Epoch 170/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 171/1000
# 7499/7499 [==============================] - 5s 726us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0017
# Epoch 172/1000
# 7499/7499 [==============================] - 5s 697us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 173/1000
# 7499/7499 [==============================] - 5s 687us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 174/1000
# 7499/7499 [==============================] - 5s 686us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 175/1000
# 7499/7499 [==============================] - 5s 702us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 176/1000
# 7499/7499 [==============================] - 5s 710us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 177/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 178/1000
# 7499/7499 [==============================] - 5s 706us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 179/1000
# 7499/7499 [==============================] - 5s 704us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 180/1000
# 7499/7499 [==============================] - 5s 714us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 181/1000
# 7499/7499 [==============================] - 5s 701us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 182/1000
# 7499/7499 [==============================] - 5s 700us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 183/1000
# 7499/7499 [==============================] - 5s 707us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 184/1000
# 7499/7499 [==============================] - 5s 698us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 185/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 186/1000
# 7499/7499 [==============================] - 5s 709us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 187/1000
# 7499/7499 [==============================] - 5s 703us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 188/1000
# 7499/7499 [==============================] - 5s 694us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 189/1000
# 7499/7499 [==============================] - 5s 698us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 190/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 191/1000
# 7499/7499 [==============================] - 5s 704us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 192/1000
# 7499/7499 [==============================] - 5s 717us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 193/1000
# 7499/7499 [==============================] - 5s 704us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 194/1000
# 7499/7499 [==============================] - 5s 675us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 195/1000
# 7499/7499 [==============================] - 5s 677us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 196/1000
# 7499/7499 [==============================] - 5s 684us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 197/1000
# 7499/7499 [==============================] - 5s 675us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 198/1000
# 7499/7499 [==============================] - 5s 706us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 199/1000
# 7499/7499 [==============================] - 6s 748us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 200/1000
# 7499/7499 [==============================] - 6s 738us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 201/1000
# 7499/7499 [==============================] - 6s 745us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 202/1000
# 7499/7499 [==============================] - 5s 732us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 203/1000
# 7499/7499 [==============================] - 5s 729us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 204/1000
# 7499/7499 [==============================] - 5s 678us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 205/1000
# 7499/7499 [==============================] - 5s 692us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 206/1000
# 7499/7499 [==============================] - 5s 705us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 207/1000
# 7499/7499 [==============================] - 5s 689us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 208/1000
# 7499/7499 [==============================] - 5s 709us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 209/1000
# 7499/7499 [==============================] - 6s 746us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 210/1000
# 7499/7499 [==============================] - 5s 709us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 211/1000
# 7499/7499 [==============================] - 6s 747us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 212/1000
# 7499/7499 [==============================] - 5s 709us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 213/1000
# 7499/7499 [==============================] - 5s 691us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 214/1000
# 7499/7499 [==============================] - 5s 699us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0018 - val_last_time_step_mse: 0.0015
# Epoch 215/1000
# 7499/7499 [==============================] - 6s 791us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 216/1000
# 7499/7499 [==============================] - 5s 722us/sample - loss: 0.0017 - last_time_step_mse: 0.0015 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 217/1000
# 7499/7499 [==============================] - 5s 722us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 218/1000
# 7499/7499 [==============================] - 6s 745us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 219/1000
# 7499/7499 [==============================] - 6s 748us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 220/1000
# 7499/7499 [==============================] - 5s 733us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 221/1000
# 7499/7499 [==============================] - 5s 719us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# Epoch 222/1000
# 7499/7499 [==============================] - 5s 682us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 223/1000
# 7499/7499 [==============================] - 5s 700us/sample - loss: 0.0017 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0015
# (10, 1)
# (10, 1)
# (10,)
