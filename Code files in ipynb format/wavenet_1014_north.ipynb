# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1015_north.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o[175:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)

flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
#TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_test.shape)
print(X_test[-1:].shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

#MODEL
def last_time_step_mse(Y_true, Y_pred):
     return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=1000,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("vawenet_1014_north.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MIN FORECAST
#50 MIN FORECAST
#flow
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time (in 5 minutes intervals)")
    plt.ylabel('Volume (veh/h)')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (1020, 50, 1)
# (1, 50, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7138 samples, validate on 2040 samples
# Epoch 1/1000
# 7138/7138 [==============================] - 5s 692us/sample - loss: 0.0411 - last_time_step_mse: 0.0365 - val_loss: 0.0100 - val_last_time_step_mse: 0.0091
# Epoch 2/1000
# 7138/7138 [==============================] - 5s 632us/sample - loss: 0.0092 - last_time_step_mse: 0.0088 - val_loss: 0.0088 - val_last_time_step_mse: 0.0081
# Epoch 3/1000
# 7138/7138 [==============================] - 4s 608us/sample - loss: 0.0084 - last_time_step_mse: 0.0079 - val_loss: 0.0081 - val_last_time_step_mse: 0.0075
# Epoch 4/1000
# 7138/7138 [==============================] - 4s 602us/sample - loss: 0.0081 - last_time_step_mse: 0.0075 - val_loss: 0.0091 - val_last_time_step_mse: 0.0087
# Epoch 5/1000
# 7138/7138 [==============================] - 4s 609us/sample - loss: 0.0080 - last_time_step_mse: 0.0073 - val_loss: 0.0079 - val_last_time_step_mse: 0.0072
# Epoch 6/1000
# 7138/7138 [==============================] - 4s 609us/sample - loss: 0.0078 - last_time_step_mse: 0.0072 - val_loss: 0.0079 - val_last_time_step_mse: 0.0073
# Epoch 7/1000
# 7138/7138 [==============================] - 4s 606us/sample - loss: 0.0078 - last_time_step_mse: 0.0071 - val_loss: 0.0076 - val_last_time_step_mse: 0.0069
# Epoch 8/1000
# 7138/7138 [==============================] - 4s 609us/sample - loss: 0.0077 - last_time_step_mse: 0.0070 - val_loss: 0.0080 - val_last_time_step_mse: 0.0072
# Epoch 9/1000
# 7138/7138 [==============================] - 4s 596us/sample - loss: 0.0076 - last_time_step_mse: 0.0069 - val_loss: 0.0074 - val_last_time_step_mse: 0.0068
# Epoch 10/1000
# 7138/7138 [==============================] - 4s 601us/sample - loss: 0.0075 - last_time_step_mse: 0.0068 - val_loss: 0.0073 - val_last_time_step_mse: 0.0067
# Epoch 11/1000
# 7138/7138 [==============================] - 4s 613us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0076 - val_last_time_step_mse: 0.0066
# Epoch 46/1000
# 7138/7138 [==============================] - 4s 612us/sample - loss: 0.0070 - last_time_step_mse: 0.0062 - val_loss: 0.0082 - val_last_time_step_mse: 0.0075
# Epoch 47/1000
# 7138/7138 [==============================] - 4s 618us/sample - loss: 0.0070 - last_time_step_mse: 0.0062 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 48/1000
# 7138/7138 [==============================] - 4s 624us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 49/1000
# 7138/7138 [==============================] - 4s 625us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0070 - val_last_time_step_mse: 0.0062
# Epoch 50/1000
# 7138/7138 [==============================] - 4s 608us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0068 - val_last_time_step_mse: 0.0061
# Epoch 51/1000
# 7138/7138 [==============================] - 4s 606us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0071 - val_last_time_step_mse: 0.0063
# Epoch 52/1000
# 7138/7138 [==============================] - 4s 593us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 53/1000
# 7138/7138 [==============================] - 4s 603us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 54/1000
# 7138/7138 [==============================] - 4s 607us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0073 - val_last_time_step_mse: 0.0066
# Epoch 55/1000
# 7138/7138 [==============================] - 4s 610us/sample - loss: 0.0069 - last_time_step_mse: 0.0061 - val_loss: 0.0072 - val_last_time_step_mse: 0.0064
# Epoch 56/1000
# 7138/7138 [==============================] - 4s 599us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0068 - val_last_time_step_mse: 0.0059
# Epoch 57/1000
# 7138/7138 [==============================] - 4s 610us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0072 - val_last_time_step_mse: 0.0064
# Epoch 58/1000
# 7138/7138 [==============================] - 4s 606us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0069 - val_last_time_step_mse: 0.0061
# Epoch 59/1000
# 7138/7138 [==============================] - 4s 602us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 60/1000
# 7138/7138 [==============================] - 4s 608us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0074 - val_last_time_step_mse: 0.0067
# Epoch 61/1000
# 7138/7138 [==============================] - 4s 611us/sample - loss: 0.0069 - last_time_step_mse: 0.0060 - val_loss: 0.0068 - val_last_time_step_mse: 0.0061
# Epoch 62/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 63/1000
# 7138/7138 [==============================] - 5s 639us/sample - loss: 0.0068 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0060
# Epoch 64/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0071 - val_last_time_step_mse: 0.0062
# Epoch 65/1000
# 7138/7138 [==============================] - 5s 634us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0073 - val_last_time_step_mse: 0.0066
# Epoch 66/1000
# 7138/7138 [==============================] - 5s 634us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0068 - val_last_time_step_mse: 0.0059
# Epoch 67/1000
# 7138/7138 [==============================] - 5s 631us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0070 - val_last_time_step_mse: 0.0061
# Epoch 68/1000
# 7138/7138 [==============================] - 5s 648us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0070 - val_last_time_step_mse: 0.0062
# Epoch 69/1000
# 7138/7138 [==============================] - 5s 638us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0075 - val_last_time_step_mse: 0.0066
# Epoch 70/1000
# 7138/7138 [==============================] - 5s 640us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0071 - val_last_time_step_mse: 0.0063
# Epoch 71/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 72/1000
# 7138/7138 [==============================] - 5s 633us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0074 - val_last_time_step_mse: 0.0067
# Epoch 73/1000
# 7138/7138 [==============================] - 5s 636us/sample - loss: 0.0068 - last_time_step_mse: 0.0060 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 74/1000
# 7138/7138 [==============================] - 5s 634us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 75/1000
# 7138/7138 [==============================] - 5s 638us/sample - loss: 0.0068 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0061
# Epoch 76/1000
# 7138/7138 [==============================] - 5s 638us/sample - loss: 0.0068 - last_time_step_mse: 0.0059 - val_loss: 0.0070 - val_last_time_step_mse: 0.0061
# Epoch 77/1000
# 7138/7138 [==============================] - 5s 645us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0061
# Epoch 78/1000
# 7138/7138 [==============================] - 5s 638us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0066 - val_last_time_step_mse: 0.0058
# Epoch 79/1000
# 7138/7138 [==============================] - 5s 631us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0061
# Epoch 80/1000
# 7138/7138 [==============================] - 4s 628us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0066 - val_last_time_step_mse: 0.0058
# Epoch 81/1000
# 7138/7138 [==============================] - 5s 643us/sample - loss: 0.0067 - last_time_step_mse: 0.0058 - val_loss: 0.0066 - val_last_time_step_mse: 0.0059
# Epoch 82/1000
# 7138/7138 [==============================] - 4s 630us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 83/1000
# 7138/7138 [==============================] - 5s 632us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0058
# Epoch 84/1000
# 7138/7138 [==============================] - 5s 639us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 85/1000
# 7138/7138 [==============================] - 5s 632us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# Epoch 86/1000
# 7138/7138 [==============================] - 4s 627us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0066 - val_last_time_step_mse: 0.0058
# Epoch 87/1000
# 7138/7138 [==============================] - 5s 663us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0074 - val_last_time_step_mse: 0.0066
# Epoch 88/1000
# 7138/7138 [==============================] - 5s 665us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0069 - val_last_time_step_mse: 0.0062
# Epoch 89/1000
# 7138/7138 [==============================] - 4s 602us/sample - loss: 0.0067 - last_time_step_mse: 0.0058 - val_loss: 0.0070 - val_last_time_step_mse: 0.0061
# Epoch 90/1000
# 7138/7138 [==============================] - 4s 613us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 91/1000
# 7138/7138 [==============================] - 4s 602us/sample - loss: 0.0067 - last_time_step_mse: 0.0058 - val_loss: 0.0067 - val_last_time_step_mse: 0.0060
# Epoch 92/1000
# 7138/7138 [==============================] - 4s 612us/sample - loss: 0.0067 - last_time_step_mse: 0.0058 - val_loss: 0.0070 - val_last_time_step_mse: 0.0063
# Epoch 93/1000
# 7138/7138 [==============================] - 4s 616us/sample - loss: 0.0067 - last_time_step_mse: 0.0059 - val_loss: 0.0068 - val_last_time_step_mse: 0.0060
# Epoch 94/1000
# 7138/7138 [==============================] - 4s 629us/sample - loss: 0.0067 - last_time_step_mse: 0.0058 - val_loss: 0.0067 - val_last_time_step_mse: 0.0060
# Epoch 95/1000
# 7138/7138 [==============================] - 5s 664us/sample - loss: 0.0066 - last_time_step_mse: 0.0058 - val_loss: 0.0067 - val_last_time_step_mse: 0.0059
# (10, 1)
# (10, 1)
# (10,)
