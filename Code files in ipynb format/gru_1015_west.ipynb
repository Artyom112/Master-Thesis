# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1015_west.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)
flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)

#TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_test.shape)
print(X_test[-1:].shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

#DEFINE AND COMPILE MODEL
model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(forecast))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("gru_1016_west.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MIN FORECAST
#flow
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time (in 5 minutes intervals)")
    plt.ylabel('Volume (veh/h)')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (1072, 50, 1)
# (1, 50, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7499 samples, validate on 2142 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0166 - last_time_step_mse: 0.0145 - val_loss: 0.0052 - val_last_time_step_mse: 0.0037
# Epoch 2/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0045 - last_time_step_mse: 0.0034 - val_loss: 0.0041 - val_last_time_step_mse: 0.0034
# Epoch 3/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0038 - last_time_step_mse: 0.0033 - val_loss: 0.0036 - val_last_time_step_mse: 0.0034
# Epoch 4/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0035 - last_time_step_mse: 0.0033 - val_loss: 0.0034 - val_last_time_step_mse: 0.0032
# Epoch 5/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0034 - last_time_step_mse: 0.0032 - val_loss: 0.0033 - val_last_time_step_mse: 0.0032
# Epoch 6/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0032 - last_time_step_mse: 0.0030 - val_loss: 0.0032 - val_last_time_step_mse: 0.0029
# Epoch 7/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0031 - last_time_step_mse: 0.0028 - val_loss: 0.0030 - val_last_time_step_mse: 0.0028
# Epoch 8/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0029 - last_time_step_mse: 0.0027 - val_loss: 0.0030 - val_last_time_step_mse: 0.0028
# Epoch 9/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0029 - last_time_step_mse: 0.0027 - val_loss: 0.0029 - val_last_time_step_mse: 0.0027
# Epoch 10/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0028 - last_time_step_mse: 0.0027 - val_loss: 0.0028 - val_last_time_step_mse: 0.0027
# Epoch 11/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0028 - last_time_step_mse: 0.0026 - val_loss: 0.0027 - val_last_time_step_mse: 0.0026
# Epoch 12/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0027 - last_time_step_mse: 0.0026 - val_loss: 0.0027 - val_last_time_step_mse: 0.0026
# Epoch 13/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0027 - last_time_step_mse: 0.0026 - val_loss: 0.0027 - val_last_time_step_mse: 0.0027
# Epoch 14/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0026 - last_time_step_mse: 0.0025 - val_loss: 0.0027 - val_last_time_step_mse: 0.0025
# Epoch 15/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0026 - last_time_step_mse: 0.0025 - val_loss: 0.0026 - val_last_time_step_mse: 0.0024
# Epoch 16/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0026 - last_time_step_mse: 0.0025 - val_loss: 0.0026 - val_last_time_step_mse: 0.0025
# Epoch 17/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0026 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0024
# Epoch 18/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0025 - last_time_step_mse: 0.0024 - val_loss: 0.0026 - val_last_time_step_mse: 0.0025
# Epoch 19/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0025 - last_time_step_mse: 0.0024 - val_loss: 0.0025 - val_last_time_step_mse: 0.0024
# Epoch 20/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 21/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0023
# Epoch 22/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0025 - last_time_step_mse: 0.0023 - val_loss: 0.0026 - val_last_time_step_mse: 0.0024
# Epoch 23/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0023 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 24/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0023 - val_loss: 0.0024 - val_last_time_step_mse: 0.0023
# Epoch 25/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0025 - val_last_time_step_mse: 0.0022
# Epoch 26/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 27/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 28/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 29/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 30/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 31/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0024 - last_time_step_mse: 0.0022 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 32/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 33/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0024 - val_last_time_step_mse: 0.0022
# Epoch 34/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0022
# Epoch 35/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 36/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 37/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 38/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 39/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0022
# Epoch 40/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 41/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 42/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 43/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 44/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 45/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 46/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0021 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 47/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 48/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 49/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 50/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 51/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 52/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0021
# Epoch 53/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0023 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 54/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0021
# Epoch 55/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0023 - val_last_time_step_mse: 0.0020
# Epoch 56/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 57/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 58/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 59/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 60/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 61/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 62/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 63/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 64/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 65/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 66/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 67/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0020 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 68/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 69/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 70/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0023 - val_last_time_step_mse: 0.0020
# Epoch 71/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 72/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 73/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 74/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0019
# Epoch 75/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 76/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 77/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 78/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 79/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0019
# Epoch 80/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 81/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 82/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 83/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0019
# Epoch 84/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 85/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 86/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 87/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0019
# Epoch 88/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0022 - last_time_step_mse: 0.0019 - val_loss: 0.0023 - val_last_time_step_mse: 0.0020
# Epoch 89/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0019
# Epoch 90/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 91/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0019
# Epoch 92/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 93/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 94/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 95/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 96/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 97/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 98/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 99/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 100/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 101/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 102/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 103/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0019 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 104/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 105/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 106/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 107/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 108/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 109/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 110/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 111/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 112/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0022 - val_last_time_step_mse: 0.0020
# Epoch 113/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 114/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 115/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 116/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 117/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 118/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 119/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0018
# Epoch 120/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0018
# Epoch 121/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 122/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0021 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 123/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 124/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 125/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 126/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0018
# Epoch 127/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 128/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 129/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 130/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 131/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 132/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 133/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0019
# Epoch 134/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 135/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 136/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 137/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 138/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0020
# Epoch 139/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 140/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 141/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 142/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 143/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 144/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 145/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 146/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 147/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 148/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 149/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 150/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 151/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 152/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 153/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 154/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 155/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 156/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 157/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 158/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0021 - val_last_time_step_mse: 0.0019
# Epoch 159/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 160/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0018 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 161/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 162/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 163/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 164/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 165/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 166/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 167/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 168/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 169/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 170/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 171/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 172/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 173/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 174/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0021 - val_last_time_step_mse: 0.0018
# Epoch 175/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 176/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 177/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 178/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 179/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 180/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 181/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0017
# Epoch 182/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 183/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 184/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 185/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 186/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0020 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 187/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 188/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 189/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 190/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0020 - val_last_time_step_mse: 0.0018
# Epoch 191/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 192/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 193/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 194/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 195/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 196/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 197/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 198/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 199/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 200/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 201/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 202/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 203/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 204/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 205/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 206/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 207/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 208/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 209/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 210/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 211/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 212/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 213/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 214/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 215/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0018
# Epoch 216/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 217/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 218/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 219/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 220/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 221/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 222/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 223/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 224/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 225/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 226/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 227/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 228/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 229/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 230/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 231/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 232/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 233/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 234/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 235/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 236/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0017 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 237/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 238/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 239/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 240/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 241/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 242/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0016
# Epoch 243/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 244/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 245/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 246/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 247/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 248/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 249/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 250/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 251/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 252/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 253/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 254/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 255/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 256/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 257/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 258/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 259/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 260/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0019 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 261/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 262/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 263/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 264/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 265/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 266/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 267/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 268/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 269/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0019 - val_last_time_step_mse: 0.0017
# Epoch 270/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 271/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 272/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 273/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 274/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 275/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 276/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 277/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 278/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0018 - last_time_step_mse: 0.0016 - val_loss: 0.0018 - val_last_time_step_mse: 0.0016
# Epoch 279/700
# ...
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 479/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 480/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 481/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 482/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 483/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 484/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 485/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 486/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 487/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 488/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 489/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 490/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 491/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 492/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 493/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 494/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 495/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 496/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 497/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 498/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 499/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 500/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 501/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 502/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 503/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 504/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 505/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 506/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 507/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 508/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 509/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 510/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 511/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0017 - val_last_time_step_mse: 0.0014
# Epoch 512/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 513/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 514/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 515/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0014 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 516/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 517/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 518/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 519/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 520/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 521/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 522/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 523/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 524/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 525/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 526/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 527/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 528/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 529/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 530/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 531/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 532/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 533/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 534/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 535/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 536/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 537/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 538/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 539/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 540/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 541/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 542/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 543/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 544/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 545/700
# 7499/7499 [==============================] - 12s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 546/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 547/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 548/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 549/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0014
# Epoch 550/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 551/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 552/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 553/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 554/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 555/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 556/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 557/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 558/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 559/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 560/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 561/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 562/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 563/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 564/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 565/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 566/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 567/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 568/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 569/700
# 7499/7499 [==============================] - 11s 1ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 570/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# Epoch 571/700
# 7499/7499 [==============================] - 11s 2ms/sample - loss: 0.0016 - last_time_step_mse: 0.0013 - val_loss: 0.0016 - val_last_time_step_mse: 0.0013
# (10, 1)
# (10, 1)
# (10,)
