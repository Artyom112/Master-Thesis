# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

n_steps = 50
forecast = 10

#EXTRACT FLOW, Z SCORE, OUTLIERS
data_west = pd.read_csv('denoised_data_1016_east.csv')
data_west_o = np.array(data_west.FLOW)

#EXRTEND DATA
array_to_concatinate = data_west_o[288:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

#SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)

flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
#TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train = flow_reshaped[:test, :n_steps]
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]
print(X_test.shape)
print(X_test[-1:].shape)

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

#MODEL
def last_time_step_mse(Y_true, Y_pred):
     return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("vawenet_1016_east.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])

#50 MIN FORECAST
#flow
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time")
    plt.ylabel('Volume')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (1055, 50, 1)
# (1, 50, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 7381 samples, validate on 2109 samples
# Epoch 1/700
# 7381/7381 [==============================] - 5s 706us/sample - loss: 0.0136 - last_time_step_mse: 0.0126 - val_loss: 0.0058 - val_last_time_step_mse: 0.0053
# Epoch 2/700
# 7381/7381 [==============================] - 4s 607us/sample - loss: 0.0054 - last_time_step_mse: 0.0052 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 3/700
# 7381/7381 [==============================] - 5s 610us/sample - loss: 0.0051 - last_time_step_mse: 0.0048 - val_loss: 0.0049 - val_last_time_step_mse: 0.0042
# Epoch 4/700
# 7381/7381 [==============================] - 5s 615us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 5/700
# 7381/7381 [==============================] - 5s 618us/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 6/700
# 7381/7381 [==============================] - 5s 616us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0039
# Epoch 7/700
# 7381/7381 [==============================] - 5s 616us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 8/700
# 7381/7381 [==============================] - 5s 615us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 9/700
# 7381/7381 [==============================] - 5s 628us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0044 - val_last_time_step_mse: 0.0038
# Epoch 10/700
# 7381/7381 [==============================] - 5s 624us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 11/700
# 7381/7381 [==============================] - 5s 630us/sample - loss: 0.0043 - last_time_step_mse: 0.0039 - val_loss: 0.0045 - val_last_time_step_mse: 0.0039
# Epoch 12/700
# 7381/7381 [==============================] - 5s 640us/sample - loss: 0.0043 - last_time_step_mse: 0.0039 - val_loss: 0.0042 - val_last_time_step_mse: 0.0036
# Epoch 13/700
# 7381/7381 [==============================] - 5s 638us/sample - loss: 0.0043 - last_time_step_mse: 0.0038 - val_loss: 0.0042 - val_last_time_step_mse: 0.0036
# Epoch 14/700
# 7381/7381 [==============================] - 5s 643us/sample - loss: 0.0042 - last_time_step_mse: 0.0038 - val_loss: 0.0042 - val_last_time_step_mse: 0.0035
# Epoch 15/700
# 7381/7381 [==============================] - 5s 649us/sample - loss: 0.0042 - last_time_step_mse: 0.0037 - val_loss: 0.0042 - val_last_time_step_mse: 0.0035
# Epoch 16/700
# 7381/7381 [==============================] - 5s 646us/sample - loss: 0.0042 - last_time_step_mse: 0.0037 - val_loss: 0.0041 - val_last_time_step_mse: 0.0035
# Epoch 17/700
# 7381/7381 [==============================] - 5s 647us/sample - loss: 0.0042 - last_time_step_mse: 0.0037 - val_loss: 0.0043 - val_last_time_step_mse: 0.0036
# Epoch 18/700
# 7381/7381 [==============================] - 5s 653us/sample - loss: 0.0041 - last_time_step_mse: 0.0036 - val_loss: 0.0041 - val_last_time_step_mse: 0.0034
# Epoch 19/700
# 7381/7381 [==============================] - 5s 651us/sample - loss: 0.0041 - last_time_step_mse: 0.0036 - val_loss: 0.0041 - val_last_time_step_mse: 0.0034
# Epoch 20/700
# 7381/7381 [==============================] - 5s 649us/sample - loss: 0.0041 - last_time_step_mse: 0.0036 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 21/700
# 7381/7381 [==============================] - 5s 651us/sample - loss: 0.0041 - last_time_step_mse: 0.0035 - val_loss: 0.0040 - val_last_time_step_mse: 0.0034
# Epoch 22/700
# 7381/7381 [==============================] - 5s 652us/sample - loss: 0.0041 - last_time_step_mse: 0.0035 - val_loss: 0.0041 - val_last_time_step_mse: 0.0033
# Epoch 23/700
# 7381/7381 [==============================] - 5s 651us/sample - loss: 0.0040 - last_time_step_mse: 0.0035 - val_loss: 0.0042 - val_last_time_step_mse: 0.0035
# Epoch 24/700
# 7381/7381 [==============================] - 5s 645us/sample - loss: 0.0040 - last_time_step_mse: 0.0035 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 25/700
# 7381/7381 [==============================] - 5s 660us/sample - loss: 0.0040 - last_time_step_mse: 0.0035 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 26/700
# 7381/7381 [==============================] - 5s 653us/sample - loss: 0.0040 - last_time_step_mse: 0.0035 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 27/700
# 7381/7381 [==============================] - 5s 660us/sample - loss: 0.0040 - last_time_step_mse: 0.0034 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 28/700
# 7381/7381 [==============================] - 5s 660us/sample - loss: 0.0040 - last_time_step_mse: 0.0035 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 29/700
# 7381/7381 [==============================] - 5s 657us/sample - loss: 0.0040 - last_time_step_mse: 0.0034 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 30/700
# 7381/7381 [==============================] - 5s 659us/sample - loss: 0.0040 - last_time_step_mse: 0.0034 - val_loss: 0.0043 - val_last_time_step_mse: 0.0035
# Epoch 31/700
# 7381/7381 [==============================] - 5s 659us/sample - loss: 0.0039 - last_time_step_mse: 0.0034 - val_loss: 0.0040 - val_last_time_step_mse: 0.0033
# Epoch 32/700
# 7381/7381 [==============================] - 5s 661us/sample - loss: 0.0039 - last_time_step_mse: 0.0034 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 33/700
# 7381/7381 [==============================] - 5s 670us/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 34/700
# 7381/7381 [==============================] - 5s 682us/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 35/700
# 7381/7381 [==============================] - 5s 662us/sample - loss: 0.0039 - last_time_step_mse: 0.0034 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 36/700
# 7381/7381 [==============================] - 5s 661us/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 37/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 38/700
# 7381/7381 [==============================] - 5s 668us/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 39/700
# 7381/7381 [==============================] - 5s 666us/sample - loss: 0.0039 - last_time_step_mse: 0.0033 - val_loss: 0.0039 - val_last_time_step_mse: 0.0032
# Epoch 40/700
# 7381/7381 [==============================] - 5s 672us/sample - loss: 0.0038 - last_time_step_mse: 0.0033 - val_loss: 0.0040 - val_last_time_step_mse: 0.0032
# Epoch 41/700
# 7381/7381 [==============================] - 5s 675us/sample - loss: 0.0039 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 42/700
# 7381/7381 [==============================] - 5s 714us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0039 - val_last_time_step_mse: 0.0033
# Epoch 43/700
# 7381/7381 [==============================] - 5s 687us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0041 - val_last_time_step_mse: 0.0034
# Epoch 44/700
# 7381/7381 [==============================] - 5s 668us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 45/700
# 7381/7381 [==============================] - 5s 675us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 46/700
# 7381/7381 [==============================] - 5s 643us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 47/700
# 7381/7381 [==============================] - 5s 657us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 48/700
# 7381/7381 [==============================] - 5s 662us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 49/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 50/700
# 7381/7381 [==============================] - 5s 668us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 51/700
# 7381/7381 [==============================] - 5s 662us/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 52/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 53/700
# 7381/7381 [==============================] - 5s 669us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 54/700
# 7381/7381 [==============================] - 5s 663us/sample - loss: 0.0038 - last_time_step_mse: 0.0032 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 55/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0038 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 56/700
# 7381/7381 [==============================] - 5s 667us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 57/700
# 7381/7381 [==============================] - 5s 669us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 58/700
# 7381/7381 [==============================] - 5s 661us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0038 - val_last_time_step_mse: 0.0031
# Epoch 59/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 60/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 61/700
# 7381/7381 [==============================] - 5s 673us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 62/700
# 7381/7381 [==============================] - 5s 664us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 63/700
# 7381/7381 [==============================] - 5s 666us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 64/700
# 7381/7381 [==============================] - 5s 667us/sample - loss: 0.0037 - last_time_step_mse: 0.0031 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 65/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 66/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 67/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 68/700
# 7381/7381 [==============================] - 5s 668us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 69/700
# 7381/7381 [==============================] - 5s 672us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 70/700
# 7381/7381 [==============================] - 5s 675us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 71/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 72/700
# 7381/7381 [==============================] - 5s 669us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 73/700
# 7381/7381 [==============================] - 5s 666us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 74/700
# 7381/7381 [==============================] - 5s 657us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0039 - val_last_time_step_mse: 0.0031
# Epoch 75/700
# 7381/7381 [==============================] - 5s 659us/sample - loss: 0.0037 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 76/700
# 7381/7381 [==============================] - 5s 651us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 77/700
# 7381/7381 [==============================] - 5s 663us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 78/700
# 7381/7381 [==============================] - 5s 664us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 79/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 80/700
# 7381/7381 [==============================] - 5s 664us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 81/700
# 7381/7381 [==============================] - 5s 653us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 82/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 83/700
# 7381/7381 [==============================] - 5s 665us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 84/700
# 7381/7381 [==============================] - 5s 674us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 85/700
# 7381/7381 [==============================] - 5s 674us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 86/700
# 7381/7381 [==============================] - 5s 677us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 87/700
# 7381/7381 [==============================] - 5s 672us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 88/700
# 7381/7381 [==============================] - 5s 677us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 89/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 90/700
# 7381/7381 [==============================] - 5s 676us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 91/700
# 7381/7381 [==============================] - 5s 675us/sample - loss: 0.0036 - last_time_step_mse: 0.0030 - val_loss: 0.0037 - val_last_time_step_mse: 0.0030
# Epoch 92/700
# 7381/7381 [==============================] - 5s 677us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 93/700
# 7381/7381 [==============================] - 5s 671us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 94/700
# 7381/7381 [==============================] - 5s 679us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0037 - val_last_time_step_mse: 0.0029
# Epoch 95/700
# 7381/7381 [==============================] - 5s 679us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 96/700
# 7381/7381 [==============================] - 5s 721us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 97/700
# 7381/7381 [==============================] - 5s 682us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 98/700
# 7381/7381 [==============================] - 5s 668us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0038 - val_last_time_step_mse: 0.0030
# Epoch 99/700
# 7381/7381 [==============================] - 5s 673us/sample - loss: 0.0036 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 100/700
# 7381/7381 [==============================] - 5s 684us/sample - loss: 0.0035 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# Epoch 101/700
# 7381/7381 [==============================] - 5s 674us/sample - loss: 0.0035 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0029
# Epoch 102/700
# 7381/7381 [==============================] - 5s 683us/sample - loss: 0.0035 - last_time_step_mse: 0.0029 - val_loss: 0.0036 - val_last_time_step_mse: 0.0028
# (10, 1)
# (10, 1)
# (10,)
