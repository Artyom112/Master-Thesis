# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import sklearn
import sys
import io

n_steps = 50
forecast = 10

def plot_learning_curves(loss, val_loss):
    plt.figure()
    plt.plot(np.arange(len(loss)), loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)), val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

#LOAD DATA
data_west = pd.read_csv('denoised_data_1016_east.csv')
data_west_o = np.array(data_west.FLOW)
# #EXRTEND DATA
array_to_concatinate = data_west_o[288:]
for iter in range (35):
    data_west_o = np.concatenate([data_west_o,array_to_concatinate])

# #SCALE AND RESHAPE DATA
scaler = MinMaxScaler()
array = data_west_o.reshape(-1, 1)
array_scaled = scaler.fit_transform(array)
flow_reshaped = array_scaled[:(len(array_scaled) - (len(array_scaled) % (n_steps+forecast)))].reshape(-1, (n_steps+forecast), 1)
print(flow_reshaped.shape)

# #TRAIN SET, VALIDATION SET, TEST SET
test = int(0.7 * flow_reshaped.shape[0])
valid = int(0.9 * flow_reshaped.shape[0])

X_train= flow_reshaped[:test, :n_steps] #first 50, last 10
X_valid = flow_reshaped[test:valid, :n_steps]
X_test = flow_reshaped[valid:, :n_steps]

#prepare targets
Y = np.empty((flow_reshaped.shape[0], n_steps, forecast))
for step_ahead in range(1, forecast + 1):
    Y[:, :, step_ahead - 1] = flow_reshaped[:, step_ahead:step_ahead + n_steps, 0]

y_train = Y[:test]
y_valid = Y[test:valid]
y_test = Y[valid:]

# # NEW MODEL TO FIT HYPERPARAMETERS
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True), 
    keras.layers.TimeDistributed(keras.layers.Dense(forecast))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer="adam",  metrics=[last_time_step_mse])

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=700,
                    validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])

model.save("rnn_1016_east.h5")
plot_learning_curves(history.history["loss"], history.history["val_loss"])


#50 minutes forecast
flow_unscaled = array[:(len(array) - (len(array) % (n_steps + forecast)))].reshape(-1, (n_steps + forecast), 1)
y_test_unscaled = flow_unscaled[valid:, n_steps:, 0]
y_real_rescaled = y_test_unscaled[-1, :].reshape(-1, 1)
print(y_real_rescaled.shape)

flow_not_reshaped = array[:(len(array) - (len(array) % (n_steps+forecast)))]

#flow prediction
y_pred = model.predict(X_test[-1, :].reshape(-1, n_steps, 1)) #shape (1, 50, 10)
y_pred = y_pred[-1,-1,:].reshape(-1,1)
y_pred_rescaled = scaler.inverse_transform(y_pred).reshape(-1, 1) #shape (10, 1)
print(y_pred_rescaled.shape)

#time
time_not_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))])
time_reshaped = np.array(data_west['TIME'][:(len(data_west['TIME']) - (len(data_west['TIME']) % (n_steps+forecast)))]).\
    reshape(-1, (n_steps+forecast), 1)

valid_time = int(0.9 * time_reshaped.shape[0])
y_time_test = time_reshaped[valid_time:, n_steps:, 0]
print(y_time_test[-1, :].shape)

def plot_prediction(y_real_resacled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test):
    plt.figure()
    plt.title("50 minutes prediction", fontsize=14)
    plt.plot(time_not_reshaped[-300:-forecast], flow_not_reshaped[-300:-forecast], 'b-')
    plt.plot(y_time_test[-1, :], y_real_resacled, 'ro-', label = 'Real values')
    plt.plot(y_time_test[-1, :], y_pred_rescaled, 'gx-', label = 'Predicted values')
    plt.legend(loc="upper left")
    plt.xlabel("Time")
    plt.ylabel('Volume')

plot_prediction(y_real_rescaled, y_pred_rescaled, flow_not_reshaped, time_not_reshaped, y_time_test)

plt.show()
# Out:
# (10545, 60, 1)
# Train on 7381 samples, validate on 2109 samples
# Epoch 1/700
# 7381/7381 [==============================] - 4s 492us/sample - loss: 0.0185 - last_time_step_mse: 0.0176 - val_loss: 0.0075 - val_last_time_step_mse: 0.0069
# Epoch 2/700
# 7381/7381 [==============================] - 3s 407us/sample - loss: 0.0067 - last_time_step_mse: 0.0064 - val_loss: 0.0064 - val_last_time_step_mse: 0.0060
# Epoch 3/700
# 7381/7381 [==============================] - 3s 411us/sample - loss: 0.0062 - last_time_step_mse: 0.0061 - val_loss: 0.0062 - val_last_time_step_mse: 0.0059
# Epoch 4/700
# 7381/7381 [==============================] - 3s 421us/sample - loss: 0.0061 - last_time_step_mse: 0.0059 - val_loss: 0.0061 - val_last_time_step_mse: 0.0058
# Epoch 5/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0060 - last_time_step_mse: 0.0059 - val_loss: 0.0060 - val_last_time_step_mse: 0.0057
# Epoch 6/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0060 - last_time_step_mse: 0.0059 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 7/700
# 7381/7381 [==============================] - 3s 407us/sample - loss: 0.0059 - last_time_step_mse: 0.0058 - val_loss: 0.0060 - val_last_time_step_mse: 0.0057
# Epoch 8/700
# 7381/7381 [==============================] - 3s 399us/sample - loss: 0.0059 - last_time_step_mse: 0.0058 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 9/700
# 7381/7381 [==============================] - 3s 402us/sample - loss: 0.0059 - last_time_step_mse: 0.0058 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 10/700
# 7381/7381 [==============================] - 3s 399us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 11/700
# 7381/7381 [==============================] - 3s 401us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0057
# Epoch 12/700
# 7381/7381 [==============================] - 3s 407us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 13/700
# 7381/7381 [==============================] - 3s 422us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 14/700
# 7381/7381 [==============================] - 3s 401us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0055
# Epoch 15/700
# 7381/7381 [==============================] - 3s 397us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 16/700
# 7381/7381 [==============================] - 3s 406us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 17/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 18/700
# 7381/7381 [==============================] - 3s 434us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 19/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 20/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 21/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 22/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 23/700
# 7381/7381 [==============================] - 3s 433us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 24/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 25/700
# 7381/7381 [==============================] - 3s 423us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 26/700
# 7381/7381 [==============================] - 3s 418us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0059 - val_last_time_step_mse: 0.0056
# Epoch 27/700
# 7381/7381 [==============================] - 3s 418us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 28/700
# 7381/7381 [==============================] - 3s 409us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0056
# Epoch 29/700
# 7381/7381 [==============================] - 3s 430us/sample - loss: 0.0058 - last_time_step_mse: 0.0057 - val_loss: 0.0058 - val_last_time_step_mse: 0.0055
# Epoch 30/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0058 - last_time_step_mse: 0.0056 - val_loss: 0.0057 - val_last_time_step_mse: 0.0054
# Epoch 31/700
# 7381/7381 [==============================] - 3s 433us/sample - loss: 0.0057 - last_time_step_mse: 0.0056 - val_loss: 0.0058 - val_last_time_step_mse: 0.0053
# Epoch 32/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0057 - last_time_step_mse: 0.0055 - val_loss: 0.0057 - val_last_time_step_mse: 0.0052
# Epoch 33/700
# 7381/7381 [==============================] - 3s 428us/sample - loss: 0.0056 - last_time_step_mse: 0.0054 - val_loss: 0.0056 - val_last_time_step_mse: 0.0050
# Epoch 34/700
# 7381/7381 [==============================] - 3s 403us/sample - loss: 0.0055 - last_time_step_mse: 0.0053 - val_loss: 0.0057 - val_last_time_step_mse: 0.0051
# Epoch 35/700
# 7381/7381 [==============================] - 3s 410us/sample - loss: 0.0054 - last_time_step_mse: 0.0051 - val_loss: 0.0054 - val_last_time_step_mse: 0.0047
# Epoch 36/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0053 - last_time_step_mse: 0.0051 - val_loss: 0.0054 - val_last_time_step_mse: 0.0048
# Epoch 37/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0053 - last_time_step_mse: 0.0050 - val_loss: 0.0053 - val_last_time_step_mse: 0.0047
# Epoch 38/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0053 - last_time_step_mse: 0.0050 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 39/700
# 7381/7381 [==============================] - 3s 433us/sample - loss: 0.0052 - last_time_step_mse: 0.0049 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 40/700
# 7381/7381 [==============================] - 3s 418us/sample - loss: 0.0052 - last_time_step_mse: 0.0049 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 41/700
# 7381/7381 [==============================] - 3s 418us/sample - loss: 0.0052 - last_time_step_mse: 0.0049 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 42/700
# 7381/7381 [==============================] - 3s 427us/sample - loss: 0.0052 - last_time_step_mse: 0.0049 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 43/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0051 - last_time_step_mse: 0.0049 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 44/700
# 7381/7381 [==============================] - 3s 421us/sample - loss: 0.0051 - last_time_step_mse: 0.0049 - val_loss: 0.0053 - val_last_time_step_mse: 0.0047
# Epoch 45/700
# 7381/7381 [==============================] - 3s 422us/sample - loss: 0.0051 - last_time_step_mse: 0.0049 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 46/700
# 7381/7381 [==============================] - 3s 409us/sample - loss: 0.0051 - last_time_step_mse: 0.0048 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 47/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0051 - last_time_step_mse: 0.0048 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 48/700
# 7381/7381 [==============================] - 3s 429us/sample - loss: 0.0051 - last_time_step_mse: 0.0048 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 49/700
# 7381/7381 [==============================] - 3s 405us/sample - loss: 0.0051 - last_time_step_mse: 0.0048 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 50/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0051 - last_time_step_mse: 0.0048 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 51/700
# 7381/7381 [==============================] - 3s 408us/sample - loss: 0.0050 - last_time_step_mse: 0.0048 - val_loss: 0.0052 - val_last_time_step_mse: 0.0046
# Epoch 52/700
# 7381/7381 [==============================] - 3s 425us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0051 - val_last_time_step_mse: 0.0045
# Epoch 53/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 54/700
# 7381/7381 [==============================] - 3s 436us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 55/700
# 7381/7381 [==============================] - 3s 428us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 56/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 57/700
# 7381/7381 [==============================] - 3s 413us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 58/700
# 7381/7381 [==============================] - 3s 425us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0050 - val_last_time_step_mse: 0.0043
# Epoch 59/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0050 - last_time_step_mse: 0.0047 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 60/700
# 7381/7381 [==============================] - 3s 425us/sample - loss: 0.0049 - last_time_step_mse: 0.0046 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 61/700
# 7381/7381 [==============================] - 3s 408us/sample - loss: 0.0049 - last_time_step_mse: 0.0046 - val_loss: 0.0050 - val_last_time_step_mse: 0.0043
# Epoch 62/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0049 - last_time_step_mse: 0.0046 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 63/700
# 7381/7381 [==============================] - 3s 429us/sample - loss: 0.0049 - last_time_step_mse: 0.0046 - val_loss: 0.0050 - val_last_time_step_mse: 0.0045
# Epoch 64/700
# 7381/7381 [==============================] - 3s 423us/sample - loss: 0.0049 - last_time_step_mse: 0.0046 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 65/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 66/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0049 - last_time_step_mse: 0.0046 - val_loss: 0.0049 - val_last_time_step_mse: 0.0042
# Epoch 67/700
# 7381/7381 [==============================] - 3s 434us/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0050 - val_last_time_step_mse: 0.0044
# Epoch 68/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 69/700
# 7381/7381 [==============================] - 3s 436us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 70/700
# 7381/7381 [==============================] - 3s 430us/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 71/700
# 7381/7381 [==============================] - 3s 427us/sample - loss: 0.0049 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 72/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0049 - val_last_time_step_mse: 0.0042
# Epoch 73/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 74/700
# 7381/7381 [==============================] - 3s 411us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0049 - val_last_time_step_mse: 0.0042
# Epoch 75/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 76/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 77/700
# 7381/7381 [==============================] - 3s 419us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 78/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 79/700
# 7381/7381 [==============================] - 3s 419us/sample - loss: 0.0048 - last_time_step_mse: 0.0045 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 80/700
# 7381/7381 [==============================] - 3s 428us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 81/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0049 - val_last_time_step_mse: 0.0043
# Epoch 82/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 83/700
# 7381/7381 [==============================] - 3s 418us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 84/700
# 7381/7381 [==============================] - 3s 427us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 85/700
# 7381/7381 [==============================] - 3s 413us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 86/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0048 - last_time_step_mse: 0.0044 - val_loss: 0.0047 - val_last_time_step_mse: 0.0041
# Epoch 87/700
# 7381/7381 [==============================] - 3s 431us/sample - loss: 0.0047 - last_time_step_mse: 0.0044 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 88/700
# 7381/7381 [==============================] - 3s 432us/sample - loss: 0.0047 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0040
# Epoch 89/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0048 - val_last_time_step_mse: 0.0042
# Epoch 90/700
# 7381/7381 [==============================] - 3s 426us/sample - loss: 0.0047 - last_time_step_mse: 0.0044 - val_loss: 0.0048 - val_last_time_step_mse: 0.0041
# Epoch 91/700
# 7381/7381 [==============================] - 3s 441us/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 92/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0048 - val_last_time_step_mse: 0.0040
# Epoch 93/700
# 7381/7381 [==============================] - 3s 406us/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 94/700
# 7381/7381 [==============================] - 3s 429us/sample - loss: 0.0047 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 95/700
# 7381/7381 [==============================] - 3s 410us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 96/700
# 7381/7381 [==============================] - 3s 411us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 97/700
# 7381/7381 [==============================] - 3s 436us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 98/700
# 7381/7381 [==============================] - 3s 408us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 99/700
# 7381/7381 [==============================] - 3s 423us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 100/700
# 7381/7381 [==============================] - 3s 404us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 101/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 102/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 103/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 104/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 105/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 106/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 107/700
# 7381/7381 [==============================] - 3s 407us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 108/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 109/700
# 7381/7381 [==============================] - 3s 411us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 110/700
# 7381/7381 [==============================] - 3s 408us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 111/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 112/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0046 - last_time_step_mse: 0.0043 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 113/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 114/700
# 7381/7381 [==============================] - 3s 411us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0047 - val_last_time_step_mse: 0.0040
# Epoch 115/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0046 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 116/700
# 7381/7381 [==============================] - 3s 423us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 117/700
# 7381/7381 [==============================] - 3s 403us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 118/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 119/700
# 7381/7381 [==============================] - 3s 413us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 120/700
# 7381/7381 [==============================] - 3s 413us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 121/700
# 7381/7381 [==============================] - 3s 410us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 122/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 123/700
# 7381/7381 [==============================] - 3s 431us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0039
# Epoch 124/700
# 7381/7381 [==============================] - 3s 426us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 125/700
# 7381/7381 [==============================] - 3s 423us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0039
# Epoch 126/700
# 7381/7381 [==============================] - 3s 404us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0046 - val_last_time_step_mse: 0.0038
# Epoch 127/700
# 7381/7381 [==============================] - 3s 415us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 128/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 129/700
# 7381/7381 [==============================] - 3s 407us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 130/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 131/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0038
# Epoch 132/700
# 7381/7381 [==============================] - 3s 418us/sample - loss: 0.0045 - last_time_step_mse: 0.0042 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 133/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 134/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 135/700
# 7381/7381 [==============================] - 3s 411us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 136/700
# 7381/7381 [==============================] - 3s 452us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 137/700
# 7381/7381 [==============================] - 3s 420us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 138/700
# 7381/7381 [==============================] - 3s 425us/sample - loss: 0.0044 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0040
# Epoch 139/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 140/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 141/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 142/700
# 7381/7381 [==============================] - 3s 419us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 143/700
# 7381/7381 [==============================] - 3s 449us/sample - loss: 0.0045 - last_time_step_mse: 0.0041 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 144/700
# 7381/7381 [==============================] - 3s 417us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 145/700
# 7381/7381 [==============================] - 3s 414us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 146/700
# 7381/7381 [==============================] - 3s 413us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0045 - val_last_time_step_mse: 0.0037
# Epoch 147/700
# 7381/7381 [==============================] - 3s 416us/sample - loss: 0.0044 - last_time_step_mse: 0.0041 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 148/700
# 7381/7381 [==============================] - 3s 422us/sample - loss: 0.0044 - last_time_step_mse: 0.0041 - val_loss: 0.0046 - val_last_time_step_mse: 0.0039
# Epoch 149/700
# 7381/7381 [==============================] - 3s 432us/sample - loss: 0.0044 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0038
# Epoch 150/700
# 7381/7381 [==============================] - 3s 412us/sample - loss: 0.0044 - last_time_step_mse: 0.0041 - val_loss: 0.0045 - val_last_time_step_mse: 0.0037
# Epoch 151/700
# 7381/7381 [==============================] - 3s 434us/sample - loss: 0.0044 - last_time_step_mse: 0.0041 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 152/700
# 7381/7381 [==============================] - 3s 424us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 153/700
# 7381/7381 [==============================] - 3s 434us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# Epoch 154/700
# 7381/7381 [==============================] - 3s 439us/sample - loss: 0.0044 - last_time_step_mse: 0.0040 - val_loss: 0.0044 - val_last_time_step_mse: 0.0037
# (10, 1)
# (10, 1)
# (10,)
